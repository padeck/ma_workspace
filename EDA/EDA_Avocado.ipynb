# %% [markdown]
# # EDA for Avocado Dataset

# %%
import pandas as pd

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/padeck/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_parquet("../data/avocado_train.parquet", engine="pyarrow")

# %%
df.head()
# Out:
#                                                 messageid sender_access  \
# 467607  <FC38A9406AA4D411AB62009027DE9DA5DFC9F9@ntmach...            EX
# 357399  <20000915190431.2397B58C1@bugzilla.avocadoit.com>          SMTP
# 510235    <01370F5B01AAD411BE8100D0B744338C17E08B@HQEXCH>            EX
# 321924  <FC38A9406AA4D411AB62009027DE9DA5013BCFFC@ntma...            EX
# 495901  <01370F5B01AAD411BE8100D0B744338C756389@ntmach...            EX
#
#                            outlook_sender_name outlook_recipient_name  \
# 467607                            Robert Moore               Dan Baca
# 357399  bugzilla-daemon@bugzilla.avocadoit.com    Jyothsna Amancherla
# 510235                         Laura Henderson                   None
# 321924                            Craig Harper               Hung Hua
# 495901                                Dan Baca                   None
#
#                                            sentto_address  \
# ...

# %%
# Step 1: Extract the email text column
text_column = df['extracted_text']

# Step 2: Get the list of English stop words
stop_words = set(stopwords.words('english'))

# Step 3: Preprocess text (lowercasing, removing punctuation, stop words, and tokenizing)
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation and non-alphabetic characters using regex
    text = re.sub(r'[^\w\s]', '', text)
    # Split text into individual words (tokenize)
    words = text.split()
    # Remove stop words
    words = [word for word in words if word not in stop_words]
    return words

# Step 4: Combine all the rows into one list of words
all_words = []
for text in text_column:
    all_words.extend(preprocess_text(text))

# Step 5: Use Counter to count word frequencies
word_counts = Counter(all_words)
# Step 6: Get the 5 most common words
most_common_words = word_counts.most_common(5)

# Output the result
print("The 5 most common words are:")
for word, count in most_common_words:
    print(f"{word}: {count}")

# %%
# Out:
# The 5 most common words are:
# 2001: 1079666
# edt: 997424
# exec: 866777
# rn: 680144
# jul: 562169
