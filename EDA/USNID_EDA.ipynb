# %%
import pandas as pd

# %%
df = pd.read_csv('unsupervised_clustering_result.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0                                               Text  Cluster
# 0            0               scala regex multiple block capturing       16
# 1            1             use oracle 6 from asp. net application       15
# 2            2                   hql 1 to many count ( ) question        7
# 3            3              scala syntax highlighting in bluefish       16
# 4            4                               weird bindings issue        4
# 5            5  why this keyboard intercepting kernel extensio...       13
# 6            6  test sending emails from sharepoint without sm...        1
# 7            7                           cell and array in matlab       16
# 8            8         how do i call an oracle function from oci?        3
# 9            9  typed fp : tuple arguments and curriable argum...        8
# 10          10  do i still need to learn about managing memory...       13
# ...
