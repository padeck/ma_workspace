# %%
import pandas as pd

# %%
df = pd.read_csv('results_semisupervised.csv')

# %%
df.loc[( (df['seed']==0))].sort_values('known_cls_ratio')
# Out:
#       NMI    ARI    ACC  dataset method    backbone  known_cls_ratio  \
# 0   73.57  42.96  56.49  banking  USNID  bert_USNID             0.25
# 1   73.57  42.96  56.49  banking  USNID  bert_USNID             0.25
# 4   48.26  10.10  31.98  avocado  USNID  bert_USNID             0.25
# 2   76.34  46.98  60.78  banking  USNID  bert_USNID             0.50
# 5   48.23   5.98  29.65  avocado  USNID  bert_USNID             0.50
# 3   76.76  46.24  58.05  banking  USNID  bert_USNID             0.75
# 6   42.42   3.01  25.00  avocado  USNID  bert_USNID             0.75
# 17  45.86   4.91  28.49  avocado  USNID  bert_USNID             1.00
#
#     labeled_ratio  cluster_num_factor  \
# 0             0.1                 1.0
# 1             0.1                 1.0
# 4             0.1                 1.0
# 2             0.1                 1.0
# 5             0.1                 1.0
# 3             0.1                 1.0
# 6             0.1                 1.0
# ...
