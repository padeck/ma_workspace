# %% [markdown]
# # Split Dataset and create Target Sentence Column

# %%
import pandas as pd
import re
from sklearn.model_selection import train_test_split
import spacy
from tqdm import tqdm
tqdm.pandas()  # Integrate tqdm with pandas

# %%
df = pd.read_parquet('../avocado-1.0.2/avocado_extracted_text.parquet', engine='pyarrow')

# %%
# First, split the data into training+validation (80%) and test sets (20%)
train_val_df, df_test = train_test_split(df, test_size=0.2, random_state=42)

# Then, split the train+val set into training (75% of train+val, which is 60% of total) and validation (25% of train+val, which is 20% of total)
df_train, df_val = train_test_split(train_val_df, test_size=0.25, random_state=42)  # 0.25 * 0.8 = 0.2

# %% [markdown]
# ## Split Dataset into 60:20:20 Train/Eval/Test

# %%
df_test.shape
# Out:
# (187592, 17)

# %%
df_val.shape
# Out:
# (187592, 17)

# %%
df_train.shape
# Out:
# (562774, 17)

# %%
#df_train.to_parquet('avocado_train.parquet', engine='pyarrow', compression='snappy')

# %%
df_val.shape[0] * 3
# Out:
# 562776

# %% [markdown]
# ## Intent Extraction with Heuristics

# %%
df['heuristics'] = ''

def filter_df(row):
    text = row['extracted_text'].lower()  # Convert to lower case for case-insensitive comparison
    if any(keyword in text for keyword in ['please', 'can you', '?']):
        return 'pos'
    return ''

# Apply the function to update the heuristics column
df['heuristics'] = df.apply(filter_df, axis=1)

# %%
# Filter the DataFrame based on the updated heuristics column
df_pos = df[df['heuristics'] == 'pos']

# %%
df_pos.to_parquet('avocado_train.parquet', engine='pyarrow', compression='snappy')

# %%
df_pos.head()
# Out:
#                                             messageid sender_access  \
# 0   <FC38A9406AA4D411AB62009027DE9DA5E6545D@HQEXCH01>            EX
# 1     <19B3B310D020D311B57E00105A9A55241D5975@COFFEE>            EX
# 3     <9640A23C9075D411B5CB00D0B708160C23A93D@COFFEE>            EX
# 6     <19B3B310D020D311B57E00105A9A55245BE600@COFFEE>            EX
# 10    <19B3B310D020D311B57E00105A9A5524557278@COFFEE>            EX
#
#     outlook_sender_name outlook_recipient_name          sentto_address  \
# 0     Fortunata Hermoso             Meshele Ko              Meshele Ko
# 1   Paiman Komeilizadeh             Meshele Ko           All Employees
# 3            Meshele Ko                   None   'jbmcbryde@fedex.com'
# 6            Meshele Ko                   None  'eileenw@getsmart.com'
# 10     Debbie Margulies             Meshele Ko           All Employees
#
#                                        cc_address  \
# 0   'ray_rahamin@hp.com'; Dan Baca; Elba Linscott
# 1                                            None
# 3                                            None
# 6                                            None
# 10                                           None
#
#                                               subject  \
# 0   Fw: RE: AvocadoIT's CEO committed to winning B...
# 1            Expense reimbursement request- Amendment
# 3                                               Fedex
# 6                                    RE: GetSmart.com
# 10                                      Photo touchup
#
#                                     processed_subject             sent_date  \
# 0   AvocadoIT's CEO committed to winning Banamex deal  2001-04-12T22:02:41Z
# 1            Expense reimbursement request- Amendment  2000-04-24T23:06:06Z
# 3                                               Fedex  2000-09-12T17:01:08Z
# 6                                        GetSmart.com  2000-05-13T01:00:03Z
# 10                                      Photo touchup  2000-04-04T04:57:20Z
#
#             arrival_date              body_file_path  \
# 0   2001-04-12T22:02:41Z  text/162/162-000001-EM.txt
# 1   2000-04-24T23:06:15Z  text/162/162-000003-EM.txt
# 3   2000-09-12T17:01:08Z  text/162/162-000005-EM.txt
# 6   2000-05-13T01:00:03Z  text/162/162-000009-EM.txt
# 10  2000-04-04T04:57:30Z  text/162/162-000017-EM.txt
#
#                                          body_content  \
# 0   From: "Fortunata Hermoso" <fortunata.hermoso@a...
# 1   From: "Paiman Komeilizadeh" <pkomeilizadeh@avo...
# 3   From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...
# 6   From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...
# 10  From: "Debbie Margulies" <dmargulies@avocadoit...
#
#                                           in_reply_to Keywords  \
# 0                                                None     None
# 1                                                None     None
# 3                                                None     None
# 6   <35153F4F88CFD311B33300104B95BC493DD197@arabia...     None
# 10                                               None     None
#
#                                        extracted_text preceding_conversation  \
# 0   Fyi on Venks commitment on Banamex. The next s...                   None
# 1   Dear  friends,\r\n\r\n\r\nTo expedite the expe...                   None
# 3   Hello Jim,\r\n\r\nI am following up on a piece...                   None
# 6   Eileen,\r\n\r\nAvocadoIT is a vendor that take...                   None
# 10  does anyone know how to touch up a photo in ph...                   None
#
#    problematic heuristics
# 0         None        pos
# 1         None        pos
# 3         None        pos
# 6         None        pos
# 10        None        pos

# %% [markdown]
# # SpaCy Stuff

# %%
nlp = spacy.load('en_core_web_lg')
nlp.max_length = 10000000  # Increase as needed

# %%
df_pos['target_sentence'] = ''
keywords = {"please", "kindly", "can you", "could you", "would you", "would it", "i need", "i want", "send", "provide", "do this", "let me know"}

def find_target_sentence(text):
    doc = nlp(text.lower())

    # Split into sentences
    sentences = list(doc.sents)
    for sent in sentences:
        words = set(str(sent).split())
        if not keywords.isdisjoint(words):
            return sent

# Apply the function to update the heuristics column
df_pos['target_sentence'] = df_pos['extracted_text'].progress_apply(find_target_sentence)
# Out:
# /var/folders/vh/4lm899sj0tdgnf9d98kzk1800000gn/T/ipykernel_78523/3214482979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos['target_sentence'] = ''
# 100%|██████████| 448790/448790 [8:39:02<00:00, 14.41it/s]
# /var/folders/vh/4lm899sj0tdgnf9d98kzk1800000gn/T/ipykernel_78523/3214482979.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos['target_sentence'] = df_pos['extracted_text'].progress_apply(find_target_sentence)

# %%
df_pos.head(10)
# Out:
#                                             messageid sender_access  \
# 0   <FC38A9406AA4D411AB62009027DE9DA5E6545D@HQEXCH01>            EX
# 1     <19B3B310D020D311B57E00105A9A55241D5975@COFFEE>            EX
# 3     <9640A23C9075D411B5CB00D0B708160C23A93D@COFFEE>            EX
# 6     <19B3B310D020D311B57E00105A9A55245BE600@COFFEE>            EX
# 10    <19B3B310D020D311B57E00105A9A5524557278@COFFEE>            EX
# 12    <9640A23C9075D411B5CB00D0B708160C23A862@COFFEE>            EX
# 18    <19B3B310D020D311B57E00105A9A55240B4670@COFFEE>            EX
# 21    <19B3B310D020D311B57E00105A9A55245BE715@COFFEE>            EX
# 26    <19B3B310D020D311B57E00105A9A55240B452C@COFFEE>            EX
# 27    <19B3B310D020D311B57E00105A9A55240B46C0@COFFEE>            EX
#
#     outlook_sender_name outlook_recipient_name  \
# 0     Fortunata Hermoso             Meshele Ko
# 1   Paiman Komeilizadeh             Meshele Ko
# 3            Meshele Ko                   None
# 6            Meshele Ko                   None
# 10     Debbie Margulies             Meshele Ko
# 12           Meshele Ko                   None
# 18           Meshele Ko                   None
# 21           Meshele Ko                   None
# 26           Meshele Ko                   None
# 27           Meshele Ko                   None
#
#                                        sentto_address  \
# 0                                          Meshele Ko
# 1                                       All Employees
# 3                               'jbmcbryde@fedex.com'
# 6                              'eileenw@getsmart.com'
# 10                                      All Employees
# 12                            'mark.ebel@bestbuy.com'
# 18                                  Best Buy (E-mail)
# 21                          'greg@messageblaster.com'
# 26  Lisa Chui; Mike Scolari; John Schemena; Dan De...
# 27                          'Flavia.Spasiano@diax.ch'
#
#                                        cc_address  \
# 0   'ray_rahamin@hp.com'; Dan Baca; Elba Linscott
# 1                                            None
# 3                                            None
# 6                                            None
# 10                                           None
# 12                                           None
# 18                                           None
# 21                                           None
# 26                                    Kelsey Kerr
# 27                                           None
#
#                                               subject  \
# 0   Fw: RE: AvocadoIT's CEO committed to winning B...
# 1            Expense reimbursement request- Amendment
# 3                                               Fedex
# 6                                    RE: GetSmart.com
# 10                                      Photo touchup
# 12                                              hello
# 18                   Non-PC access to Web application
# 21                                 AvocadoIT Wireless
# 26                             United Healthcare Demo
# 27                   Non-PC access to Web application
#
#                                     processed_subject             sent_date  \
# 0   AvocadoIT's CEO committed to winning Banamex deal  2001-04-12T22:02:41Z
# 1            Expense reimbursement request- Amendment  2000-04-24T23:06:06Z
# 3                                               Fedex  2000-09-12T17:01:08Z
# 6                                        GetSmart.com  2000-05-13T01:00:03Z
# 10                                      Photo touchup  2000-04-04T04:57:20Z
# 12                                              hello  2000-08-25T00:16:19Z
# 18             Wireless connection to Web application  2000-01-03T22:07:50Z
# 21                                 AvocadoIT Wireless  2000-06-03T01:10:13Z
# 26                                        Re[2]: Demo  1999-11-15T17:50:04Z
# 27             Wireless connection to Web application  2000-01-17T17:48:31Z
#
#             arrival_date              body_file_path  \
# 0   2001-04-12T22:02:41Z  text/162/162-000001-EM.txt
# 1   2000-04-24T23:06:15Z  text/162/162-000003-EM.txt
# 3   2000-09-12T17:01:08Z  text/162/162-000005-EM.txt
# 6   2000-05-13T01:00:03Z  text/162/162-000009-EM.txt
# 10  2000-04-04T04:57:30Z  text/162/162-000017-EM.txt
# 12  2000-08-25T00:16:19Z  text/162/162-000019-EM.txt
# 18  2000-01-03T22:07:50Z  text/162/162-000029-EM.txt
# 21  2000-06-03T01:10:13Z  text/162/162-000034-EM.txt
# 26  1999-11-15T17:50:04Z  text/162/162-000040-EM.txt
# 27  2000-01-17T17:48:31Z  text/162/162-000043-EM.txt
#
#                                          body_content  \
# 0   From: "Fortunata Hermoso" <fortunata.hermoso@a...
# 1   From: "Paiman Komeilizadeh" <pkomeilizadeh@avo...
# 3   From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...
# 6   From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...
# 10  From: "Debbie Margulies" <dmargulies@avocadoit...
# 12  From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...
# 18  From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...
# 21  From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...
# 26  From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...
# 27  From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...
#
#                                           in_reply_to Keywords  \
# 0                                                None     None
# 1                                                None     None
# 3                                                None     None
# 6   <35153F4F88CFD311B33300104B95BC493DD197@arabia...     None
# 10                                               None     None
# 12                                               None     None
# 18                                               None     None
# 21                                               None     None
# 26                                               None     None
# 27                                               None     None
#
#                                        extracted_text preceding_conversation  \
# 0   Fyi on Venks commitment on Banamex. The next s...                   None
# 1   Dear  friends,\r\n\r\n\r\nTo expedite the expe...                   None
# 3   Hello Jim,\r\n\r\nI am following up on a piece...                   None
# 6   Eileen,\r\n\r\nAvocadoIT is a vendor that take...                   None
# 10  does anyone know how to touch up a photo in ph...                   None
# 12  Mark,\r\n\r\nI did get a message from Nina?.  ...                   None
# 18  Best Buy Chief Technology Officer,\r\n\r\nAs y...                   None
# 21  Greg,\r\n\r\nI wanted to follow-up with your c...                   None
# 26  Dan,\r\n\r\nThe conference call has been sched...                   None
# 27  Flavia,\r\nI appreciate your interest.  I've a...                   None
#
#    problematic heuristics                                    target_sentence
# 0         None        pos  (please, use, me, to, escalate, any, support, ...
# 1         None        pos  (2-, \t, please, make, a, copy, of, your, expe...
# 3         None        pos  (please, contact, me, with, any, questions, or...
# 6         None        pos  (can, you, please, direct, me, to, the, right,...
# 10        None        pos  (if, so, ,, please, see, me, tuesday, morning,...
# 12        None        pos                                               None
# 18        None        pos                                               None
# 21        None        pos  (please, let, me, know, how, best, to, reach, ...
# 26        None        pos  (would, it, be, possible, to, send, me, a, lis...
# 27        None        pos                                               None

# %%
def span_to_string(span):
    if isinstance(span, spacy.tokens.Span):
        return span.text
    return str(span)  # Ensure anything else is converted to string if necessary

df_pos['target_sentence'] = df_pos['target_sentence'].apply(span_to_string)
# Out:
# /var/folders/vh/4lm899sj0tdgnf9d98kzk1800000gn/T/ipykernel_78523/544037439.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pos['target_sentence'] = df_pos['target_sentence'].apply(span_to_string)

# %%
df_pos.to_parquet('avocado_target_sentences.parquet', engine='pyarrow', compression='snappy')

# %%
nr = 0
print(df_pos.iloc[nr]['target_sentence'])
print('----')
print(df_pos.iloc[nr]['extracted_text'])
# Out:
# ----
# Fyi on Venks commitment on Banamex. The next step is to set a conference call with Nicollo and Venk next week. EP is committed to do whatever it takes to close this accoiunt.
#
# We have a lot of support. Let's keep the communcation going. Please use me to escalate any support needed to close this account.
# --------------------------
# Fortunata Hermoso
# AvocadoIT, Inc.
# Global Alliance Manager
# Mobile Phone: 408.464.8998
# email: fortunata.hermoso@avocadoit.com

# %%
print(df[df['heuristics'].str.len() > 0].iloc[1]['extracted_text'])
# Out:
# Dear  friends,
#
#
# To expedite the expense report / reimbursement process and documentation, accounting department is amending the process.
#
#
# The following steps are added to expense report process:
#
# 1-	All receipts must be taped flat on regular white sheet ( you may tape 2, 3 or more to one sheet -depending on length and size of your receipts), prior to filing your expense reimbursement request with accounts payable.
#
# 2-	Please make a copy of your expense report and its documentation for your record, prior to filing your expense reimbursement request with accounts payable.
#
# 3-  	Due to the volume of invoices and vouchers we are receiving on daily basis, any expense reports which have not been prepared correctly may be returned to requester for correction. This will delay the reimbursement.
#
# 4-	All expense reports should be filed on timely basis. No actual expenditures should be more than 15 days late.
#
# 5- 	On every month end, if you have not yet prepared your expense reimbursement request,  please send an email to accounting department indicating the dollar amount and major expenses of your expenditures based on your best knowledge. This will help us to accurately record your department expense for each month. ****** monthly expense report should not be later than 10 days of the following month******  example:  April expense reimbursement request should not be filed later than May 10th*******
#
# 6- 	Expense reimbursement request should be prepared according to the month   expense incurred. Example : April expenses should be recorded on one request and May expenses should be on another request forms. Please do not mix different months expenses in one request form.
#
#
# Thank you for helping us to expedite your expense reimbursement process.
#
#
#
# Paiman Komeilizadeh
# Accounting Manager
# AvocadoIT, Inc.
# 3231 Scott Boulevard
# Santa Clara, CA  95054
# Main: 408.562.8000
# Direct: 408.562.8053
# pkomeilizadeh@avocadoit.com
# www.avocadoit.com

# %%
df.shape
# Out:
# (937958, 18)
