# %%
from bertopic import BERTopic
from scipy.cluster import hierarchy as sch
import pandas as pd
import ast
from sklearn.metrics.pairwise import cosine_distances
from tqdm import tqdm
import numpy as np
from umap import UMAP
from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer
import re
import sys
sys.path.append('../../')
from utility.utility_functions import *

# %%
df = pd.read_parquet('../../data/avocado_train.parquet')

# %%
# Read and clean signatures
with open("signatures_cleaned.txt", "r") as file:
    signature_list = [ast.literal_eval(line.strip().rstrip(',')) for line in file if line.strip()  ]

for signature in tqdm(signature_list, desc="Cleaning Signatures"):
    df['text'] = df['text'].str.replace(signature, "", regex=False)
# Out:
# Cleaning Signatures: 100%|██████████| 2240/2240 [05:24<00:00,  6.90it/s]

# %%
names = [
    "barry",
    "david",
    "george",
    "donivan",
    "shailesh",
    "nilesh",
    "ritesh",
    "andersen",
    "chris",
    "vinayak",
    "sreeni",
    "silverton",
    "lisa",
    "rajeev",
    "amitabh",
    "jeff",
    "jivaro",
    "rajeev",
    "lisa",
    "rajeev",
    "nihar",
    "rajdeep",
    "amitabh",
    "sinha",
    "tom",
    "jeff",
    "jim",
    "joe","tom","bithi","jivaro","jivaroinc","marilisa","debbie",
    "michael","mike","jivaro","jivaroinc","emma","brett","darcysalzmann",
    "andy","toshi",
    "pachipala",
    "raghavan",
    "palanisamy",
    "Ravikumar",
    "Wilhan",
    "helen",
    "sri",
    "jaime",
    "darshan",
    "mehrak",
    "rishi",
    "divakar",
    "Venk",
    "Fortunata",
    "elba",
    "Carlos",
    "venktesh",
    "prakash",
    "shukla",
    "amy",
    "kimberlie",
    "wagoner",
    "andrew",
    "garcia",
    "Glenn",
    "Martinez",
    "Simmons",
    "Susan",
    "ruyben",
    "Mitch",
    "sharyn",
    "roopak",
    "krishna",
    "Prasad",
    "srik",
    "Ravi",
    "Mary",
    "Glenn",
    "Pereira",
    "Doug",
    "douga",
    "Ray",
    "rayhan",
    "Tony",
    "Arun",
    "ricardo",
    "Dan",
    "Dave",
    "Jon",
    "Ryan",
    "Steve",
    "john",
    "Richard",
    "Matt",
    "Peter",
    "Ron",
    "germana",
    "Ann",
    "Ruth",
    "Trish",
    "Kelsey",
    "Amit",
    "Nadir",
    "fernand",
    "Hung",
    "Abinov",
    "steve",
    "meshele",
    "Ko",
    "Stuart",
    "kadanoff",
    "Marcia",
    "Chen",
    "Diana",
    "craig",
    "Chapman",
    "Sanjay",
    "salzmann",
    "D'arcy",
    "Darcy",
]

pattern = '|'.join(rf'\b{name}\b' for name in names)

# Remove the specified strings from the column (case-insensitive)
df['text'] = df['text'].str.replace(pattern, '', case=False, regex=True).str.strip()

# %%
docs = list(set(df['text'].tolist()))
len(docs)
# Out:
# 350583

# %%
# Initialize UMAP with a fixed random state
random_state = 42 # Other seeds sometimes caused negative values in the distanace matrix

# Set global random seeds
np.random.seed(random_state)

embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
umap_model = UMAP(n_neighbors=15, n_components=5, random_state=random_state)
hdbscan_model = HDBSCAN(min_cluster_size=200, prediction_data=True)

topic_model = BERTopic(verbose=True, umap_model=umap_model, hdbscan_model=hdbscan_model, embedding_model=embedding_model)
topics, probs = topic_model.fit_transform(docs)
# Out:
# 2024-11-29 15:44:18,901 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/10956 [00:00<?, ?it/s]
# 2024-11-29 15:58:20,896 - BERTopic - Embedding - Completed ✓
# 2024-11-29 15:58:20,896 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-11-29 16:03:01,843 - BERTopic - Dimensionality - Completed ✓
# 2024-11-29 16:03:01,845 - BERTopic - Cluster - Start clustering the reduced embeddings
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 2024-11-29 16:04:05,129 - BERTopic - Cluster - Completed ✓
# 2024-11-29 16:04:05,164 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-11-29 16:04:16,908 - BERTopic - Representation - Completed ✓

# %%
hierarchical_topics = topic_model.hierarchical_topics(docs)
# Out:
# 100%|██████████| 115/115 [00:00<00:00, 133.71it/s]

# %%
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)

# %%
docs_to_remove = []

# %%
# 2 - jsp
# 4 - bugzilla
# 5 - extremeprogramming
# 6 - oca
# 8 - meeting
# 9 - meeting_planning?
# 9 - testing
# 17 - conference call
# 21 - presentation slides
# 25 - flight, hotel, reservation
# 26 - schedule training
# 27 - travel, confirmed
# 28 - bugs
# 29 - siebel
# 32 - epservlet, java
# 33 - emds, emas, bug, planned

# %%
topic_id = 20
inspect_topic(topic_model,topic_id)
# Out:
# Topic: 20
#
# Top Words:
# die, und, der, mit, ich, das, bei, von, für, sie,
#
# Representative Target Sentences:
# Golem Newsletter vom 06.09.2001
# ... connected by ISION Internet AG
# _____
#
#
# Schlagzeilen:
# Microsoft verkündet WindowsCE-Nachfolger
# Zwei HP Jornadas mit neuer WindowsCE-Version
# Freies PowerVR SDK für Kyro und Kyro II erhältlich
# E-Government für Berliner Bürgerämter
# PC-Spiele werden teurer durch Euro-Umstellung
# Adobe setzt auf PixelNet bei digitaler Foto-Entwicklung
# Microsoft veröffentlicht "Linux Migration Guide"
# ConnexModem - Kabelloses 56K-Modem von AeroComm
# Infogrames und Codemasters schließen Distributionsabkommen
# Handelsblatt: Kartellwächter überprüfen heute.t-online.de
# SanDisk und Sony entwicklen nächste Memory-Stick-Generation
# Erste Netzwerkprodukte von Dell erhältlich
# Noch ein Schädling: APost verbreitet sich per E-Mail
# QuoVadis: WindowsCE im Auto-Navigationssystem
# Neue Version des Magistr-Wurm unterwegs
# Studie: Mobiltelefone drängen Telefonkarten ins Abseits
# Lara Croft Wurm tarnt sich als Windows Desktop Theme
# Rückruf: Sarotech Festplattensysteme mit FireWire und USB
# W3C verabschiedet XML-Vektorgrafik-Format SVG 1.0
# Entlassungen bei AOL Deutschland?
# StartUp verleiht Deutschen Gründerpreis
# Neue Norton Utilities bringen wenig Neues
# VATM präsentiert Umfrage zum TK-Markt in Deutschland
#
#
# _____
#
# Microsoft verkündet WindowsCE-Nachfolger
# Auf der Konferenz DEMOmobile 2001 im kalifornischen La Jolla stellt Microsoft PocketPC 2002 vor, das das bisherige PDA-Betriebssystem WindowsCE 3.0 ablösen soll, das auch unter den Namen PocketPC bekannt ist. mehr dazu bei Golem...    [zurück]
#
#
# Zwei HP Jornadas mit neuer WindowsCE-Version
# Hewlett-Packard (HP) stellt auf seiner amerikanischen Web-Präsenz zwei neue PocketPC-Modelle vor, die bereits mit der kommenden WindowsCE-Version ausgestattet sind, die den Namen PocketPC 2002 trägt. In den USA sollen die Geräte bereits im Oktober auf den Markt kommen. Wann sie ihren Weg nach Deutschland finden, ist derzeit nicht bekannt. mehr dazu bei Golem...    [zurück]
#
#
# Freies PowerVR SDK für Kyro und Kyro II erhältlich
# PowerVR Technologies bietet nun unter www.pvrdev.com auch frei zugängliche Informationen für Entwickler, welche die von STMicroelectronics gefertigten Kyro- und Kyro-II-Grafikchips unterstützen wollen. Geboten werden Programmbeispiele, Dokumentationen und Treiber. mehr dazu bei Golem...    [zurück]
#
#
# E-Government für Berliner Bürgerämter
# Die Berliner Verwaltung unternimmt einen Schritt in Sachen E-Government. Mehr als 60 Bürgerämter sollen als dezentrale Anlaufstellen der Senats- und Bezirksverwaltungen für die Bürger ausgestaltet werden. mehr dazu bei Golem...    [zurück]
#
#
# PC-Spiele werden teurer durch Euro-Umstellung
# Wie die Zeitschrift Gamestar in ihrer aktuellen Ausgabe berichtet, haben sich im Zuge der Euro-Umstellung die Preise für Computerspiele teils erheblich erhöht. Gleichzeitig gingen die Hersteller von Spielesoftware immer mehr dazu über, die Titel nur noch mit einer "Sparausstattung" zu liefern. mehr dazu bei Golem...    [zurück]
#
#
# Adobe setzt auf PixelNet bei digitaler Foto-Entwicklung
# Die PixelNet AG will mit Adobe kooperieren. Gemeinsam strebt man eine intensive Zusammenarbeit auf dem Gebiet der Einbindung von internetbasierenden, fotografischen Dienstleistungen an. In verschiedenen Stufen soll eine direkte Anbindung als "preferred Destination" der PixelNet Dienste in diversen Adobe Produkten realisiert werden. mehr dazu bei Golem...    [zurück]
#
#
# Microsoft veröffentlicht "Linux Migration Guide"
# In einer Rede an der Stern School of Business der Universität New York gab Microsoft Senior Vice President  Mundie den Startschuss zu einer Kampagne gegen OpenSource und insbesondere die GPL. Nach teilweise eher unbeholfenen Aktionen, bei denen Microsoft unter anderem Linux als Gefahr für die Software-Industrie darstellte, folgt nun das nächste Kapitel. Zusammen mit Active State und Visit 3 Leaft Solutions stellt Microsoft jetzt einen "Linux Migration Guide" online, eine Anleitung um OpenSource-basierte E-Commerce-Angebote auf Microsoft Technologien zu migrieren. mehr dazu bei Golem...    [zurück]
#
#
# ConnexModem - Kabelloses 56K-Modem von AeroComm
# Der US-Hersteller AeroComm hat ein neues drahtloses 56K-Modem angekündigt, das an die serielle Schnittstelle angeschlossen wird und eine drahtlose Verbindung zur nächsten Telefonbuchse aufbaut, in der ein weiteres Sende-/Empfangsteil steckt. Dabei sollen in Gebäuden Entfernungen von bis zu 150 Metern, im Freien gar Entfernungen im Kilometerbereich überbrückt werden können. mehr dazu bei Golem...    [zurück]
#
#
# Infogrames und Codemasters schließen Distributionsabkommen
# Infogrames wird zukünftig alle Software-Titel des britischen Entwicklers Codemasters exklusiv in Nordamerika vertreiben. Das Abkommen gilt zunächst für ein Jahr und wird voraussichtlich 17 Veröffentlichungen umfassen. mehr dazu bei Golem...    [zurück]
#
#
# Handelsblatt: Kartellwächter überprüfen heute.t-online.de
# Das Bundekartellamt will die Kooperation zwischen ZDF und T-Online bei heute.t-online.de prüfen lassen, das berichtet das Handelsblatt unter Berufung auf einen Sprecher der Behörde. Zudem plane der Verband der privaten Rundfunk- und Telekommunikationsanbieter (VPRT) eine Beschwerde in Brüssel einzureichen. mehr dazu bei Golem...    [zurück]
#
#
# SanDisk und Sony entwicklen nächste Memory-Stick-Generation
# SanDisk und Sony wollen im Bereich Memory Sticks zusammenarbeiten, das gaben die Unternehmen jetzt bekannt. Demnach wird SanDisk die von Sony stammenden Speicherriegel unter eigene Marke verkaufen und im Gegenzug Sony mit NAND-Flash-Memory versorgen. SanDisk gehört neben Panasonic und Toshiba zu den Initiatoren des Konkurrenzformats SD Memory Card. mehr dazu bei Golem...    [zurück]
#
#
# Erste Netzwerkprodukte von Dell erhältlich
# Wie angekündigt ist Dell jetzt auch im Bereich Netzwerkzubehör tätig und bietet besonders für die Bedürfnisse kleiner und mittlerer Unternehmen jetzt Netzwerk-Switches an, die unter dem Namen PowerConnet vermarktet werden. Bezogen auf den Preis, den ein einzelner Port kostet, will Dell damit in neue Niedrigpreisregionen vorstoßen. Eines der Gerät hat dabei einen Port-Preis von unter 10,- US-Dollar. mehr dazu bei Golem...    [zurück]
#
#
# Noch ein Schädling: APost verbreitet sich per E-Mail
# Die Liste der Virenwarnungen erhöht sich um ein weiteres Exemplar. Network Associates McAfee warnt vor einem kürzlich entdeckten E-Mail-Wurm namens APost. Aufgrund des Anstiegs an infizierten Anwendern - besonders aus Deutschland - ist der Wurm von den Fachleuten als "Medium on Watch" hochgestuft worden. mehr dazu bei Golem...    [zurück]
#
#
# QuoVadis: WindowsCE im Auto-Navigationssystem
# Microsoft und Borg Instruments zeigen mit dem Navigationssystem QuoVadis auf der Internationalen Automobil-Ausstellung 2001 (IAA 2001) mit WindowsCE for Automotive-Basis, eine speziell auf die Anforderungen des Automobilmarkts abgestimmte Variante von WindowsCE 3.0. mehr dazu bei Golem...    [zurück]
#
#
# Neue Version des Magistr-Wurm unterwegs
# Kaspersky Lab warnt Computerbesitzer, die Windows-Betriebssysteme einsetzen, vor einer neuen Variante des gefährlichen Wurm, der auf den Namen Magistr getauft wurde. Es seien bereits mehrere aktuelle Meldungen aus Spanien über Infektionen mit diesem überarbeiteten Wurm eingegangen, hieß es. mehr dazu bei Golem...    [zurück]
#
#
# Studie: Mobiltelefone drängen Telefonkarten ins Abseits
# Wer noch vor ein paar Jahren von unterwegs telefonieren wollte, dem blieb im öffentlichen Fernsprecher neben Kleingeld einzig die Telefonkarte als Zahlungsmethode. Diese Situation hat sich seit Ausbruch des Handybooms grundlegend verändert und entsprechend verzeichnet der Europamarkt für Telefonkarten schwere Umsatzeinbußen. Und die Talfahrt geht noch weiter: Im Jahr 2000 noch auf 1,69 Milliarden US-Dollar beziffert, soll das Marktvolumen bis 2007 auf 750 Millionen US-Dollar fallen. Allerdings rechnet die Unternehmensberatung Frost und Sullivan in ihrer neuen Analyse damit, dass der Markt dann auf diesem Niveau verbleibt. mehr dazu bei Golem...    [zurück]
#
#
# Lara Croft Wurm tarnt sich als Windows Desktop Theme
# Kaspersky Lab warnt vor einem neuen Internet-Wurm namens "Lara". Er sei der erste Schädling, der sich anhand von Desktop Themes verbreitet. Lara verbreitet sich nach Angaben des Anti-Viren-Spezialisten ausschließlich über IRC-Kanäle wobei die Trägerdatei des LaraCroft.theme-Wurms an die verbundenen Rechner gesendet wird. Der Dateiname täuscht die Anwender, weil er sich als Desktop Theme für Windows mit Motiven aus dem Film Tomb Raider ausgibt. mehr dazu bei Golem...    [zurück]
#
#
# Rückruf: Sarotech Festplattensysteme mit FireWire und USB
# Auf Grund einer Kundenreklamation wurde Gravis darauf aufmerksam, dass die durch Gravis vertriebenen FireWire-/USB Combo Gehäuse des koreanischen Herstellers Sarotech teilweise fehlerhaft sind. Deshalb hat sich das Unternehmen zu einer Rückrufaktion entschlossen. mehr dazu bei Golem...    [zurück]
#
#
# W3C verabschiedet XML-Vektorgrafik-Format SVG 1.0
# Das World Wide Web Consortium (W3C) hat das XML-Format "Scalable Vector Graphics (SVG) 1.0" als W3C Recommendation verabschiedet und damit zum Standard erklärt. Das XML-Format erlaubt die Erstellung von zweidimensionalen Vektorgrafiken, ähnlich Macromedia Flash. mehr dazu bei Golem...    [zurück]
#
#
# Entlassungen bei AOL Deutschland?
# Bei AOL Deutschland scheint düstere Stimmung zu herrschen: Nach Informationen von manager-magazin.de muss der für die Technik zuständige COO Maximilian Dichtl gehen. Damit aber nicht genug, mehr als zehn Prozent der übrigen Mitarbeiter würden ebenfalls ihren Job verlieren. mehr dazu bei Golem...    [zurück]
#
#
# StartUp verleiht Deutschen Gründerpreis
# Die Sparkassen-Finanzgruppe, das Magazin stern und McKinsey & Company bauen ihr gemeinsames Engagement in der StartUp-Initiative weiter aus. Im Juni 2002 wird erstmals der Deutsche Gründerpreis verliehen, der beispielhafte Leistungen beim Aufbau neuer Unternehmen auszeichnet. Als Partner konnte hierfür das ZDF gewonnen werden. mehr dazu bei Golem...    [zurück]
#
#
# Neue Norton Utilities bringen wenig Neues
# Symantec bringt jetzt die neue Version 2002 der Tools-Sammlung Norton Utilities in den Handel. Bis auf die Verträglichkeit mit Windows XP tat sich aber nur wenig. mehr dazu bei Golem...    [zurück]
#
#
# VATM präsentiert Umfrage zum TK-Markt in Deutschland
# Seit mehr als drei Jahren werden auch in Deutschland private Telekommunikationsdienste angeboten. Dies nahm der Verband der Anbieter von Telekommunikations- und Mehrwertdiensten (VATM) zum Anlass, durch eine aktuelle repräsentative Meinungsumfrage feststellen zu lassen, wie die neuen Angebote von den Telefonkunden beurteilt werden. mehr dazu bei Golem...    [zurück]
#
#
# _____
#
# Feedback	bitte an feedback@golem.de
# Pressemeldungen	bitte an press@golem.de
# Abbestellen	eMail an htmlunsubscribe@golem.de
# Copyright	Alle Beiträge dieses Newsletters sind urheberrechtlich geschützt. Der Newsletter darf nur weiterversendet oder in Online-Medien bereitgestellt werden, wenn dies komplett und ohne Änderungen geschieht. Impressum
# WebPage	http://www.golem.de - mehrfach täglich aktualisiert
#
# _____
# Golem Newsletter vom 24.08.2001
# ... connected by ISION Internet AG
# _____
#
#
# Schlagzeilen:
# Microsoft liefert Windows XP ab heute aus
# Adaptec: Firmware-Update soll RAID-Controller beschleunigen
# IFA: Partnersuche per Handy
# Erster Clié-PDA mit Farb-LCD für deutschen Markt angekündigt
# Fujitsu kündigt leise, robuste Notebook-Festplatten an
# Cisco stellt sich neu auf
# Met@box: Weitere Investorengruppe sagt ab
# Aldi-PC-Hersteller Medion kann weiter wachsen
# Brokat verscherbelt Tafelsilber
# Teles verkauft Apple-Händler Gravis AG
# debitel steigert Kundenzahl um 51 Prozent
# Novell: Desktops und Thin-Clients gemeinsam administrieren
# Lintec mit spezieller Senioren-Computer-Produktpalette
# Teles führt virtuelles E-Business-Bachelor-Studium ein
# Berufliche Weiterqualifizierung: 90 % würden selbst zahlen
# Neue Produkte für die GIS-Familie von Autodesk
# Tiptel-350-10-VoiceMail-Lösung für kleine Unternehmen
# SDSL-Router zur Standortvernetzung von ELSA
# SDSL-Anschluss ohne Beschränkung einen Monat testen
# Nikon - Zwei neue Kameras der Coolpix-Serie
# CDV verdient deutlich besser als erwartet
# Intel stellt neue Compiler für Linux vor
# Deutsche Telekom präsentiert Kundenprogramm HappyDigits
# T-DSL - Mehr Bandbreite für Privatkunden
# Amazon.de verrät deutsche Preise von Windows XP
# Rechnerkauf im T-Punkt - Bei T-DSL-Anmeldung billiger
# Sofa-Mentalität: Ist Service wichtiger als Datenschutz?
# Neues von Aldi: Funkmaus für 35,- DM
#
#
# _____
#
# Microsoft liefert Windows XP ab heute aus
# Microsoft hat heute offiziell begonnen, das neue Betriebssystem Windows XP offiziell an Computerhersteller auszuliefern. Die Entwicklung an Windows XP ist damit abgeschlossen, im Laden sollen die Boxen ab 25. Oktober stehen. mehr dazu bei Golem...    [zurück]
#
#
# Adaptec: Firmware-Update soll RAID-Controller beschleunigen
# Adaptec hat für seine ATA- und SCSI-RAID-Produkte 2400A, 2100S, 3200S, 3210S, 3400S und 3410S eine neue RAIDPipe getaufte Firmware veröffentlicht. Diese steht kostenlos zur Verfügung und soll eine Leistungssteigerung von bis zu 300 Prozent bringen. mehr dazu bei Golem...    [zurück]
#
#
# IFA: Partnersuche per Handy
# Während der Internationalen Funkausstellung in Berlin will Lucent die Möglichkeiten eines Dating-Dienstes über GPRS und UMTS demonstrieren. Wie solch eine Anwendung der nahen Zukunft aussehen kann, wird auf dem Stand von E-Plus während der Messe zu sehen sein. mehr dazu bei Golem...    [zurück]
#
#
# Erster Clié-PDA mit Farb-LCD für deutschen Markt angekündigt
# Sony kündigt auf der Internationalen Funkausstellung 2001 in Berlin das erste Clié-Modell mit Farb-Display für den deutschen Markt an. Der Clié PEG-N770C gleicht äußerlich dem Clié PEG-N700C, der im März erstmals in Japan gezeigt wurde. Inwiefern die Leistungsdaten übereinstimmen, ist derzeit ungewiss, weil Sony nur wenige Informationen über das neue Gerät verriet. mehr dazu bei Golem...    [zurück]
#
#
# Fujitsu kündigt leise, robuste Notebook-Festplatten an
# Fujitsu hat mit der Hornet-Serie (MHN2xxx) eine neue 2,5-Zoll-Festplatten-Familie mit Kapazitäten von 10, 15, 20 und 30 GB angekündigt. Die Plattenteller der 9,5 mm hohen UltraATA/100-Festplatten werden mit 4.200 Umdrehungen/Minute gedreht und sind flüssigkeitsgelagert. mehr dazu bei Golem...    [zurück]
#
#
# Cisco stellt sich neu auf
# Cisco Systems will sich restrukturieren und in Zukunft mit elf "Technology Groups" unter einem Dach im Bereich Engineering agieren. Der Marketingbereich soll sich zudem auf die Kommunikation von Ciscos einzigartigen Technologien konzentrieren. mehr dazu bei Golem...    [zurück]
#
#
# Met@box: Weitere Investorengruppe sagt ab
# Eine zweite Investorengruppe hat der Metabox AG gestern mitgeteilt, an einem Investment unter den gegebenen Bedingungen nicht interessiert zu sein. Über alternative Finanzierungsmöglichkeiten, u.a. von Aktionärsseite, seien die Verhandlungen noch nicht abgeschlossen. mehr dazu bei Golem...    [zurück]
#
#
# Aldi-PC-Hersteller Medion kann weiter wachsen
# Gegenüber dem Vergleichszeitraum 2000 konnte Aldi-PC-Hersteller Medion seinen Umsatz um 39 Prozent von 589,2 Millionen Euro auf 818,8 Millionen Euro steigern. Das Ergebnis vor Zinsen und Steuern (EBIT) legte deutlich überproportional um 51 Prozent zu, während der Halbjahresüberschuss, unterstützt durch die Steuerreform, um 71 Prozent von 15,4 Millionen Euro auf 26,3 Millionen Euro gesteigert werden konnte. Das Ergebnis pro Aktie erhöhte sich von 0,32 Euro auf 0,55 Euro. mehr dazu bei Golem...    [zurück]
#
#
# Brokat verscherbelt Tafelsilber
# Die Brokat Technologies AG wird den Geschäftsbereich Mobile Business für 42 Millionen Euro an das amerikanische Unternehmen eOne Global abgeben, eine Tochter der First Data Corp. Auch Brokatchef Stefan Röver verlässt das Unternehmen in Richtung eOne Global. mehr dazu bei Golem...    [zurück]
#
#
# Teles verkauft Apple-Händler Gravis AG
# Im Rahmen der Neuausrichtung des Konzerns hat der Teles-Vorstand jetzt entschieden, sich wieder vom Apple-Einzelhändler Gravis AG in Form eines Management Buy Outs (MBO) zu trennen. Teles hatte Gravis erst Ende 1999 übernommen. mehr dazu bei Golem...    [zurück]
#
#
# debitel steigert Kundenzahl um 51 Prozent
# Die debitel AG konnte ihren Teilnehmerbestand im ersten Halbjahr 2001 europaweit um 900.000 Kunden auf rund 9,5 Millionen steigern. Im Vergleich zum ersten Halbjahr 2000 bedeutet das ein Plus von 51 Prozent. Nach US-GAAP bilanziert, beziffert sich der Umsatz der debitel-Gruppe auf rund 1,2 Milliarden Euro, was im Vergleich zum ersten Halbjahr 2000 einer Steigerung von fünf Prozent entspricht. mehr dazu bei Golem...    [zurück]
#
#
# Novell: Desktops und Thin-Clients gemeinsam administrieren
# Novell bringt eine kombinierte Netzwerkmanagement-Lösung aus ZENworks for Desktops und Novell OnDemand Services 1.5 in den Handel. Firmen mit einer gemischten IT-Umgebung aus Windows-Workstations und Thin-Client-Servern können damit Web-, Client/Server- und Thin-Client-Applikationen sowie Inhalte zentral administrieren. Die Lösung unterstützt Novell NetWare, Windows NT/2000, Unix und Linux. mehr dazu bei Golem...    [zurück]
#
#
# Lintec mit spezieller Senioren-Computer-Produktpalette
# Der sächsische Computerhersteller Lintec hat einen speziell für die Belange von Senioren zugeschnittenen Rechner vorgestellt. Im Mittelpunkt der Möglichkeiten des Lintec Senior genannten Rechnerkonzepts sollen praktische Anwendungen stehen, die sich auf die spezifischen Interessen der avisierten Gruppe konzentrieren. mehr dazu bei Golem...    [zurück]
#
#
# Teles führt virtuelles E-Business-Bachelor-Studium ein
# Die Online-Akademie TEIA (Teles European Internet Academy) führt ein Weblearning-Angebot ein, mit dem man den Titel "TEIA Bachelor of E-Business Management" erwerben kann. Die Ausbildung ist von der Staatlichen Zentralstelle für Fernunterricht (ZFU) zertifiziert. mehr dazu bei Golem...    [zurück]
#
#
# Berufliche Weiterqualifizierung: 90 % würden selbst zahlen
# Mitarbeiterbindung oder beruflicher Aufstieg - die Beweggründe für Unternehmen und Mitarbeiter, Weiterbildungsmaßnahmen anzubieten bzw. in Anspruch zu nehmen, sind vielfältig. Doch über eines sind sich Chefs und Angestellte einig - berufliche Qualifizierungen sind der Schlüssel zum Erfolg. Dies ergaben zwei Befragungen, die das Jobportal StepStone unter mehr als 100 Personalmanagern deutscher Unternehmen sowie ca. 2.700 Nutzern durchführte. mehr dazu bei Golem...    [zurück]
#
#
# Neue Produkte für die GIS-Familie von Autodesk
# Mit fünf Neuheiten aus dem GIS-Bereich erweitert Autodesk die projektweite und firmenübergreifende Zusammenarbeit, die Datenintegration und die Bereitstellung von GIS-Daten direkt am Einsatzort. Autodesk Map 5, Autodesk Land Desktop 3 sowie OnSite Enterprise 2 sind ab September 2001 auf dem deutschen Markt verfügbar. mehr dazu bei Golem...    [zurück]
#
#
# Tiptel-350-10-VoiceMail-Lösung für kleine Unternehmen
# Mit dem VoiceMail-System Tiptel 350-10 ISDN sollen sich auch kleine Unternehmen auf Grund des Preises eine Sprachspeicher-Lösung leisten können, die bisher großen TK-Anlagen vorbehalten war. Das Gerät besitzt neben dem eigentlichen Firmen-Anrufbeantworter bis zu neun individuelle, PIN-geschützte Voiceboxen, die die Mitarbeiter als Arbeitsplatzanrufbeantworter einrichten können. mehr dazu bei Golem...    [zurück]
#
#
# SDSL-Router zur Standortvernetzung von ELSA
# ELSA präsentiert mit dem Lancom 1630 SDSL einen professionellen Router für den SDSL-Zugang. Das Gerät eignet sich laut Hersteller für alle Provider, die DSL mit bis zu 2.3 Mbit auf Basis der SDSL- oder G.shdsl-Technologie anbieten. mehr dazu bei Golem...    [zurück]
#
#
# SDSL-Anschluss ohne Beschränkung einen Monat testen
# Nachdem DNS:Net bereits mit einem kostenlosen 2,3-MBit-SDSL-Testangebot lockt, folgt nun auch PSINet mit einem ähnlichen Angebot: Interessierte können ab sofort einen Monat lang den DSL-Dienst speedw@y des Partners QSC für nur insgesamt 198,- Euro (inkl. 99,- Euro Aktivierungsgebühr) testen. Dafür erhält der Kunde einen symmetrischen digitalen Teilnehmeranschluss mit bis zu 2,3 MBit pro Sekunde ohne Volumen- oder Zeitbeschränkungen. mehr dazu bei Golem...    [zurück]
#
#
# Nikon - Zwei neue Kameras der Coolpix-Serie
# Nikon stellt auf der IFA 2001 in Berlin zwei neue Digitalkameras vor. Die Coolpix 775 liefert 2 Megapixel bei einer Auflösung von 1.600 x 1.200 Pixeln und wird für 1.098,- DM angeboten. Der große Bruder Coolpix 885 beherrscht bei einer Auflösung von 2048 x 1536 Bildpunkten 3,34 Megapixel und kostet 1.649,- DM. Beide unterstützen Nikons neues Online-Fotoalbum FotoShare. mehr dazu bei Golem...    [zurück]
#
#
# CDV verdient deutlich besser als erwartet
# Die CDV Software Entertainment AG hat im ersten Halbjahr 2001 einen Bruttoumsatz von 27,5 Millionen DM bzw. einen Umsatz nach Retouren von 22,8 Millionen DM erzielt. Das eigentlich leicht im Minus erwartete Halbjahresergebnis des Spielepublishers liegt bei plus 3,0 Millionen DM nach Steuern oder 1,92 Euro pro Aktie. mehr dazu bei Golem...    [zurück]
#
#
# Intel stellt neue Compiler für Linux vor
# Intel hat heute die Version 5.0 des Intel C++ Compilers für Linux und des Intel Fortran Compilers für Linux vorgestellt. Die Compiler wurden speziell entworfen, damit Entwickler die Architektur der Intel-Itanium- und Pentium-4-Prozessoren in vollem Umfang nutzen können und einen leichten Zugang zu den Leistungsmerkmalen der neuen Prozessoren von Intel erhalten. mehr dazu bei Golem...    [zurück]
#
#
# Deutsche Telekom präsentiert Kundenprogramm HappyDigits
# Punkte sammeln und diese gegen Prämien eintauschen können bald auch die Kunden der Deutschen Telekom. Zum Jahresende starten die Konzerneinheiten T-Com, T-Mobil und T-Online das Kundenbindungsprogramm HappyDigits. Zentrales Element von HappyDigits ist das Sammeln von Punkten - den Digits - die in verschiedenste Prämien umgetauscht werden können. mehr dazu bei Golem...    [zurück]
#
#
# T-DSL - Mehr Bandbreite für Privatkunden
# Die Deutsche Telekom hat mittlerweile den einmillionsten T-DSL-Anschluss installiert und gab auf einer Pressekonferenz anlässlich der IFA in Berlin einen ersten Ausblick auf neue Breitbandangebote. So plant die Telekom unter anderem einen aufgebohrten T-DSL-Anschluss mit 1,5 MBbit/s Downstream für Privatkunden und in Regionen, die mit T-DSL bisher nicht erschlossen werden konnten, ein Alternativangebot per Satellit. mehr dazu bei Golem...    [zurück]
#
#
# Amazon.de verrät deutsche Preise von Windows XP
# Der deutsche Ableger des Online-Händlers Amazon.de bietet ab sofort die Möglichkeit, das kommende Microsoft-Betriebssystem Windows XP in allen ab Oktober erhältlichen Versionen vorzubestellen. Damit stehen jetzt auch die deutschen Preise des neuen Betriebssystems fest. mehr dazu bei Golem...    [zurück]
#
#
# Rechnerkauf im T-Punkt - Bei T-DSL-Anmeldung billiger
# Was die Saarbrücker Zeitung gestern noch exklusiv berichtete ist nun offiziell: Die Telekom wird bundesweit in allen 550 T-Punkt-Shops neben der üblichen Telekommunikations-Hardware ab 27. August auch Computerpakete anbieten. Die Rechner, ein Pentium-4-Desktop-PC und ein Celeron-Notebook, stammen von Fujitsu-Siemens, bieten ein umfangreiches Zubehörpaket und sollen Kunden zur gleichzeitigen Bestellung eines T-DSL-Anschlusses animieren. mehr dazu bei Golem...    [zurück]
#
#
# Sofa-Mentalität: Ist Service wichtiger als Datenschutz?
# Das Internet wird zunehmend zur Tauschbörse für persönliche Daten - oder sogar für umfassende Kundenprofile. Laut einer Umfrage der Unternehmensberatung Mummert + Partner sind vier von fünf Verbrauchern bereit, persönliche Daten preiszugeben, wenn sie dafür personalisierten Service erhalten. "Bequemes Einkaufen und Surfen im Netz stechen die Sorgen um den Schutz sensibler Daten aus", so Wilhelm Alms, Vorstandsvorsitzender von M+P. mehr dazu bei Golem...    [zurück]
#
#
# Neues von Aldi: Funkmaus für 35,- DM
# Mit zunehmender Verbreitung von drahtlosen Peripheriegeräten hat sich nun auch eine Funkmaus zum Lebensmittel-Discounter Aldi-Nord verirrt. Ab 29. August ist sie in norddeutschen Aldi-Märkten für günstige 34,98 erhältlich. mehr dazu bei Golem...    [zurück]
#
#
# _____
#
# Feedback	bitte an feedback@golem.de
# Pressemeldungen	bitte an press@golem.de
# Abbestellen	eMail an htmlunsubscribe@golem.de
# Copyright	Alle Beiträge dieses Newsletters sind urheberrechtlich geschützt. Der Newsletter darf nur weiterversendet oder in Online-Medien bereitgestellt werden, wenn dies komplett und ohne Änderungen geschieht. Impressum
# WebPage	http://www.golem.de - mehrfach täglich aktualisiert
#
# _____
# Golem Newsletter vom 31.08.2001
# ... connected by ISION Internet AG
# _____
#
#
# Schlagzeilen:
# Trolltech zeigt Linux-basierte PDA Suite
# AmigaDE Player - AmigaDE-Anwendungen unter Linux und Windows
# HancomOffice 2.0 - Office Suite nicht nur für Linux
# Grafische Multitasking-Bedienoberfläche für DOS
# Telefonieren wird wieder teurer
# Linux-basierte Set-Top-Box aus Deutschland
# 1&1 bietet dedizierte Web-Server für 99 Euro im Monat
# Entlassungen bei LetsBuyIt.com
# eJay verordnet sich Restrukturierungsprogramm
# Tomorrow macht 7,6 Millionen Euro Verlust im 1. Halbjahr
# Computermaus ohne Kugel oder optischen Sensor
# Zeitschrift: Microsoft-e-Book-Verschlüsselung geknackt
# Talkline bringt SMS ins Festnetz
# IBM bietet ViaVoice 9 auch für Microsoft Office XP an
# Iomega stellt CD-RW-Software HotBurn vor
# Sega und Synovial wollen Segaspiele auf PDAs bringen
# Bessere Strategien mit verteilt rechnenden Schachprogrammen
# Homepage-Hoster Yoobay.NET stellt den Betrieb ein
# Post-Nachsendeaufträge jetzt online einrichtbar
# Downloadprobleme des Internet Explorer 6 behoben
# ATI All-in-Wonder Radeon 8500DV - mit TV-Tuner und Firewire
# Nero unterstützt mp3PRO
# Google siegt bei Stiftung Warentest
# LG liefert Wireless-LAN-Hardware aus
# Spieletest: MechCommander 2 - Fordernde Roboterschlachten
# Buch: Programming Linux Games - Linux-Spiele selber machen
#
#
# _____
#
# Trolltech zeigt Linux-basierte PDA Suite
# Trolltech zeigt auf der Linux World in San Francisco eine Vorabversion von Qt Palmtop 2.0, der nächsten Version von Qts PDA-Appliaktionssuite für Qt-Embedded. Nach monatelanger Entwicklung nähere man sich nun dem Final Release von Qt Palmtop 2.0, das mit verbesserter Funktionalität sowie Synchronisation mit einer Desktop PIM Suite sowie einem neuen GUI-Design aufwarten soll. mehr dazu bei Golem...    [zurück]
#
#
# AmigaDE Player - AmigaDE-Anwendungen unter Linux und Windows
# Amiga Inc. hat erneut eine Vorbestellungs-Aktion gestartet, diesmal nicht fürs AmigaDE SDK, sondern für den AmigaDE Player. Dabei handelt es sich um eine ab September für 20,- US-Dollar erhältliche Software, die Anwendungen für die AmigaDE-Plattform auch unter Linux und Windows lauffähig macht. mehr dazu bei Golem...    [zurück]
#
#
# HancomOffice 2.0 - Office Suite nicht nur für Linux
# Der koreanische Linux-Spezialist HancomLinux kooperierte mit the Kompany.com, die zahlreiche Desktop-Applikationen für KDE entwickelt haben. Gemeinsam will man mit HancomOffice 2.0 eine "intelligente" Office-Suite auf den Markt bringen, die, da sie auf Qt basiert, nicht nur unter Linux, sondern auch unter Windows und MacOS sowie auf PDAs laufen soll. Dazu eröffnet Hancom eine US-Niederlassung, die von theKompany.com-Chef Shawn Gordon geleitet wird. mehr dazu bei Golem...    [zurück]
#
#
# Grafische Multitasking-Bedienoberfläche für DOS
# Die Software-Schmiede Interactive Studio bietet mit Qube eine Vorschau-Version einer grafischen Bedienoberfläche für die DOS-Plattform kostenlos zum Download an. Noch fehlen einige Funktionen, aber das System macht auf den ersten Blick einen guten Eindruck. mehr dazu bei Golem...    [zurück]
#
#
# Telefonieren wird wieder teurer
# Wie das Statistische Bundesamt mitteilt, lagen die Preise für Telekommunikationsdienstleistungen aus Sicht der privaten Haushalte im August 2001 im Vergleich zum August 2000 um 3,7 Prozent niedriger. Im Vormonatsvergleich stieg der Index um 0,1 Prozent. mehr dazu bei Golem...    [zurück]
#
#
# Linux-basierte Set-Top-Box aus Deutschland
# Der Decoderspezialist galaxis technology ag und das Softwareunternehmen convergence integrated media GmbH schlossen am 30. August 2001 auf der Berliner Funkausstellung einen Vertrag in Millionenhöhe ab. Dabei will galaxis erstmals das von convergence entwickelte LINUX-basierte Betriebssystem für digitale Set-Top-Boxen, "LINUX TV", einsetzen. Die Spitzengeräte der Serie sollen auch kompatibel zur Multimedia Home Plattform (MHP) sein. mehr dazu bei Golem...    [zurück]
#
#
# 1&1 bietet dedizierte Web-Server für 99 Euro im Monat
# 1&1 will seine Linux-basierte Shared-Webhosting-Technologie, mit der das Unternehmen rund 2 Millionen Domains im Rechenzentrum in Karlsruhe verwaltet, künftig auch Unternehmen und Privatpersonen mit besonders hohen Anforderungen an Performance und Webspace zur Verfügung stellen. Zum 1. September 2001 stellt 1&1 Webhosting daher erstmals dedizierte Server vor. mehr dazu bei Golem...    [zurück]
#
#
# Entlassungen bei LetsBuyIt.com
# LetsBuyIt.com konnte im ersten Halbjahr 2001 gegenüber dem Vorjahreszeitraum den Verlust deutlich reduzieren. Die Abnahme der betrieblichen Aufwendungen gegenüber dem identischen Vorjahreszeitraum ist in erster Linie auf die Restrukturierung des Unternehmens im ersten Quartal 2001 sowie eine maßgebliche Reduzierung der Vertriebs- und Marketingaufwendungen zurückzuführen. mehr dazu bei Golem...    [zurück]
#
#
# eJay verordnet sich Restrukturierungsprogramm
# Mit einem straffen Restrukturierungsprogramm will die Stuttgarter eJay AG die Rückkehr zur Profitabilität schaffen. Basis der Restrukturierung bildet eine ausführliche Unternehmensanalyse, die im Juli gemeinsam mit Ebner, Stolz und Partner, Stuttgart, erstellt wurde. Daraus abgeleitet ergibt sich ein Maßnahmenpaket, mit dem die formulierten Ziele in Zukunft erreicht werden sollen. mehr dazu bei Golem...    [zurück]
#
#
# Tomorrow macht 7,6 Millionen Euro Verlust im 1. Halbjahr
# Die Tomorrow Internet AG gab heute ihre Zahlen für das erste Halbjahr 2001 bekannt. Im Konzern wurden Umsatzerlöse in Höhe von insgesamt 10,5 Millionen Euro erzielt, was einem Anstieg um 67 Prozent im Vergleich zum Vorjahreszeitraum entspricht. mehr dazu bei Golem...    [zurück]
#
#
# Computermaus ohne Kugel oder optischen Sensor
# Verdreckten Kugeln von herkömmlichen Computermäusen hat die Industrie längst mittels optischer Sensoren, die die Mechanik ersetzen, den Kampf erklärt. Auch wenn die optischen Mäuse nicht mehr verschmutzen, haben auch sie Nachteile: Schnurlose Modelle verbrauchen viel Strom für die Beleuchtung, ohne einigermaßen ebene Unterlage können sie noch immer nicht benutzt werden und an Industrie-PCs oder im medizinischen Bereich bekommen herkömmliche Mäuse immer noch Probleme. Den Problemen soll jetzt eine neue Maustechnik, die mit Beschleunigungssensoren arbeitet, Paroli bieten. mehr dazu bei Golem...    [zurück]
#
#
# Zeitschrift: Microsoft-e-Book-Verschlüsselung geknackt
# Das MIT Magazin Technology Review hat eine Story über einen angeblichen Crack von Microsofts e-Book-Code gebracht. Die Entschlüsselung soll einem bislang anonym gebliebenen Programmierer gelungen sein. mehr dazu bei Golem...    [zurück]
#
#
# Talkline bringt SMS ins Festnetz
# Talkline bietet jetzt wie E-Plus oder die Telekom seinen Mobilfunkkunden an, ab September SMS-Nachrichten ins deutsche Festnetz zu schicken. Das Produkt "SMS ins Festnetz" wandelt die Textnachricht - vorausgesetzt sie ist deutschsprachig - in eine Sprachmitteilung um. mehr dazu bei Golem...    [zurück]
#
#
# IBM bietet ViaVoice 9 auch für Microsoft Office XP an
# IBM hat die neueste Version seiner Spracherkennungssoftware ViaVoice for Windows mit der Releasenummer 9 auf den Markt gebracht. Die Software soll die Produktfamilie, die mittlerweile neben PCs auch einige Handhelds, Autocomputer und automatisierte Kundensupportsysteme unterstützt, nun auch für Office-XP-Benutzer verfügbar machen. mehr dazu bei Golem...    [zurück]
#
#
# Iomega stellt CD-RW-Software HotBurn vor
# Iomega hat seine CD-RW-Brennersoftware vorgestellt, mit der besonders Anfänger gut zurechtkommen sollen. Die Funktionen zum Musikbrennen, Datenbrennen und -Archivieren wurden unter einzelnen Programmpunkten versammelt, so dass ein aufgabenorientiertes Arbeiten möglich sein soll. mehr dazu bei Golem...    [zurück]
#
#
# Sega und Synovial wollen Segaspiele auf PDAs bringen
# Sega forciert seine Strategie, seine Spiele auf alle möglichen Plattformen zu portieren, mit einem Abkommen mit dem Wireless Multimedia Platform Provider Synovial. Sega will mit diesem einen Teil seiner Spiele auf verschiedene Mobiltelefone und Handhelds wie den Compaq iPAQ Pocket PC portieren. Dabei soll das Synovial Development Toolkit SYN Verwendung finden. mehr dazu bei Golem...    [zurück]
#
#
# Bessere Strategien mit verteilt rechnenden Schachprogrammen
# Die Anwendung EvoChess ist ein über das Internet verteiltes Softwaresystem, welches von seinen Anwendern gesteuert, aber ansonsten eigenständig, vollkommen neue Schachprogramme wachsender Spielstärke entstehen lassen soll. Hinter qoopy verbirgt sich die Idee, eine einheitliche Umgebung für verteilte, netzlastige Anwendungen zu entwickeln. mehr dazu bei Golem...    [zurück]
#
#
# Homepage-Hoster Yoobay.NET stellt den Betrieb ein
# Der kostenlose Hoster für Privathomepages Yoobay.NET stellt seinen Betrieb zum 1. Oktober 2001 ein. Yoobay.NET war der Nachfolger des 1998 gestarteten Geocity.de. Die Betreiber gaben als Grund an, dass sich Yoobay.NET anders als erwartet entwickelte. mehr dazu bei Golem...    [zurück]
#
#
# Post-Nachsendeaufträge jetzt online einrichtbar
# Unter www.umzugservice.com bietet die Deutsche Post ab sofort Hilfe im Umzugsstress an. Dort kann man den Nachsendeauftrag per Internet an die Deutsche Post senden, Firmen über Adressänderungen informieren und den gesamten Umzug strukturiert planen. mehr dazu bei Golem...    [zurück]
#
#
# Downloadprobleme des Internet Explorer 6 behoben
# Kurz nachdem am heutigen Donnerstag die offizielle Version des Internet Explorer 6.0 erschienen ist, streikte der Installations-Download des Microsoft-Browsers. Seit Donnerstagabend gegen 20.00 Uhr funktioniert der Download des Browsers wieder. mehr dazu bei Golem...    [zurück]
#
#
# ATI All-in-Wonder Radeon 8500DV - mit TV-Tuner und Firewire
# ATI hat seine All-in-Wonder-Grafikkarten-Serie um ein neues Modell erweitert, das auf dem neuen Radeon-8500-Grafikchip aufbaut, der es von der Leistung mit der GeForce3 aufnehmen und mehr 3D-Features bieten soll. Wie die All-in-Wonder-Vorgänger verwandelt die All-in-Wonder Radeon 8500DV den PC in einen digitalen MPEG-2-Videorekorder - bietet darüber hinaus aber auch erstmals Firewire-Schnittstellen und eine Fernbedienung. mehr dazu bei Golem...    [zurück]
#
#
# Nero unterstützt mp3PRO
# Das CD-Brennprogramm Nero von Ahead beherrscht in der aktuellen Version 5.5.4.0 jetzt auch den Umgang mit mp3PRO-Dateien. Dazu ist ein passender Decoder ohne jegliche Einschränkungen integriert und ein Encoder enthalten, der nur 30 Tage läuft und dann nachgekauft werden muss. mehr dazu bei Golem...    [zurück]
#
#
# Google siegt bei Stiftung Warentest
# Die Stiftung Warentest hat in der aktuellen Ausgabe 9/2001 des gleichnamigen Heftes zahlreiche deutsche Suchmaschinen unter die Lupe genommen. Klarer Sieger des Vergleichs war Google.de, dem die Tester als einzigem Probanden die Wertung "gut" verpassten. mehr dazu bei Golem...    [zurück]
#
#
# LG liefert Wireless-LAN-Hardware aus
# Der Hersteller LG Electronics hat mit der Auslieferung einer Serie von Wireless-LAN-(WLAN-)Produkten begonnen, die zum 11-MBit-Funkstandard IEEE 802.11b kompatibel sind. mehr dazu bei Golem...    [zurück]
#
#
# Spieletest: MechCommander 2 - Fordernde Roboterschlachten
# Nicht erst seit dem kürzlich erschienenen MechWarrior 4 weiß man, dass Microsoft sich im BattleTech-Universum durchaus zu Hause fühlt - die dort angesiedelten Spieleprodukte konnten bisher allesamt überzeugen. Auch MechCommander 2 - die Fortsetzung des vor knapp drei Jahren veröffentlichten Strategiespieles - steht den bisherigen Titeln kaum nach. mehr dazu bei Golem...    [zurück]
#
#
# Buch: Programming Linux Games - Linux-Spiele selber machen
# Linux mag über unschätzbare Vorteile gegenüber bisher gängigen Betriebssystemen verfügen, als passionierter Spieler wird man den Schritt weg von Windows auf Grund mangelnder Titel-Auswahl unter Linux aber wohl nur ungern vollziehen. Mit dem Buch Programming Linux Games soll diesem Umstand nun zumindest teilweise abgeholfen werden. mehr dazu bei Golem...    [zurück]
#
#
# _____
#
# Feedback	bitte an feedback@golem.de
# Pressemeldungen	bitte an press@golem.de
# Abbestellen	eMail an htmlunsubscribe@golem.de
# Copyright	Alle Beiträge dieses Newsletters sind urheberrechtlich geschützt. Der Newsletter darf nur weiterversendet oder in Online-Medien bereitgestellt werden, wenn dies komplett und ohne Änderungen geschieht. Impressum
# WebPage	http://www.golem.de - mehrfach täglich aktualisiert
#
# _____

# %%
topic_docs = inspect_topic_docs(topic_model,topic_id,docs,0)
for doc in topic_docs:
    print(repr(doc))
# Out:
# Number of Documents: 1340
#
# 'Werner,\ndeckt das Deine Erwartungen?\n\n\n\n-----Ursprüngliche Nachricht-----'
# '> Hi ,\n>\n> Wenn ich nach FRA komme (das wird sehr oft sein mit diesem Job), dann lass\n> uns ein Abend freinehmen, und auf ein Glas Wein die Welt (ver)plaudern.\n> Sabine ist herzlich eingeladen wenn Es schon mit Babysitter klappt.\n>\n> Best to la grande famille Kempf\n>\n> René\n>\n>\n>\n>'
# 'Hi Rene!\n\nMarc wollte dich gestern anrufen - hast du eine neue Handy-Nr? Haettest du\nLust auf einen Umtrunk heute abend?\n\nServus,\n\nUli.\n\nGet Your Private, Free E-mail from MSN Hotmail at http://www.hotmail.com.\n\nShare information about yourself, create your own public profile at\nhttp://profiles.msn.com.'
# 'Werner,\nPalm: müssen wir am Montag drüber reden.\n\n-----Ursprüngliche Nachricht-----'
# 'Klingt doch wirklich gut .... oder ?\n\nWerner'
# "Hallo Norbert,\n\nhey, das sind ja Neuigkeiten !\nDa moechte ich Dir ganz herzlich gratulieren ! Und was den Stress\nbetrifft - so jung wie Du noch bist, wirst Du das leicht aushalten;\naber wenn Du meinst, zur Erholung mal ein Bierchen zu brauchen, dann\nsollten wir das natuerlich tun, dann kannst Du mir auch gleich ein\npaar Bilder von den Kleinen zeigen;\n\n'Wireless Business' beschaeftigt sich mit allen 'mobile devices', also\nHandy, Pocket PC, Palm usw. - meine neue Firma kuemmert sich im speziellen\num die Verbindung dieser Geraete mit dem Internet (also etwas ganz Neues\nfuer mich - und das noch auf meine alten Tage); bisher macht's Spass,\nwenngleich es um einiges chaotischer als bei SGI zugeht);\n\nam Wochenende will ich 'mal probieren, ob's mit dem Skifahren noch klappt\n(falls genuegend Schnee liegt), ansonsten gibt's momentan nichts Neues\nzu berichten;\n\nalso, gib' meine Glueckwuensche an die Biggi weiter, und dann sollten\nwir uns 'mal Gedanken ueber einen Termin fuer ein paar Bierchen machen\n\n\nciao bis bald\nWerner"
# 'Hallo Werner, falls wir uns nach meiner Supervision treffen könnten, würde ich meine Kinder den dritten Donnerstag abends alleine zu Hause lassen müssen.Dietmar spielt Volleyball von 18.00 Uhr bis 20.00 Uhr.\nIch bin gerade viel in Sachen Elternabend, Elternsprechtag, Elternbeiratssitzung unterwegs. Also habe ich mich entschlossen unser Treffen (was sowieso noch in den Sternen stünde) doch zu vertagen! Bitte sei mir nicht böse und halte dein Versprechen mich/uns mal zu besuchen!!!!! Ganz liebe Grüße Marita'
# 'CCham35675@aol.com, DEEPSHAIL@cs.com, Elena2402 <Elena2402@pochta.ws>,\n"Fabrizio, Francis (Francis)** CTR **" <ff11@lucent.com>,\nGioiajames@aol.com, Jcrabb2@aol.com, Kwesi <ABT70@aol.com>,\nMarina Lalayants <mara_arm@yahoo.com>, WILLIAM <IANDPETER@AOL.COM>,\nvijay mistry <vbvij@yahoo.com>\n\n--part1_12c.1bf7a7fb.2b1265d0_boundary--'
# 'I have not.\n\n-----Ursprüngliche Nachricht-----'
# 'Hi Rene!\n\nDa könntest du auch mal anklopfen - obwohl die wahrscheinlich noch viel zu tun haben...'
# 'Danke, ja. Sonnig & sehr kalt.'
# 'Hallo Werner,\n\nhast Du Lust morgen ins Theatron zu gehen? Gibt Trommelmusik und Reggae\n(nacheinander, nicht gleichzeitig). Kannst ja mal schauen unter\nhttp://www.theatron.de/ . Beginn 19:00 Uhr, Eintritt frei.\n\nKaren'
# 'Werner,\nanbei das veränderte Zeugnis. Lese es in Ruhe durch, hole Dir Rat. Jegliche Änderung ist OK, baue einfach ein.'
# 'Na ja,\n\num eine weibliche Meinung dazu abzugeben - ich find die Bilder sehr schön.\nAber noch schöner find ich die von Palmer.\n\nAber - ich bin ja keine Schwedin.'
# 'ok, vielleicht koennen wir in den Biergarten gehen\nciao\nWerner'
# 'Hallo,\n\nhier die neue Brief- und Faxvorlage.\n\n\n\nBei der Faxvorlage bitte dann entsprechend den Namen und die Telefonnummer ändern.\n\nSchöne Grüße\nKatja'
# 'Thanks all!\n\n\n\n-----Ursprüngliche Nachricht-----'
# 'Great - thanks!\nUli.\n\n-----Ursprüngliche Nachricht-----'
# ',\n\nIch schicke gerne den Vertrag Morgen, glaube aber dass es schon bei den Übergabeunterlagen dabei gewesen war.\n\nSalut, René'
# 'Du hast es so gewollt, also jetzt keine Klagen! Außerdem ist der Dezember\nimmer stressig, denk nur an die vielen Weihnachtsfeiern ...\n\n-----Ursprüngliche Nachricht-----'
# 'Hallo Karen,\n\nich war bis gestern krank und kann Dir daher erst jetzt den versprochenen\nJoke schicken (nicht ganz jugendfrei);\n\nwie schaut\'s aus morgen abend ?\n\nCiao\nWerner\n\n\n>\n>\n> Ein geistlicher und ein australischer Schafhirte treten bei einem Quiz\n> gegeneinander an.\n> Nach Ablauf der regulaeren Fragerunde steht es unentschieden, und der\n> Moderator der Sendung stellt die Stichfrage,\n> die da lautet:\n> Schaffen Sie es, innerhalb von 5 Minuten einen Vers auf das\n> Wort "Timbuktu"\n> zu reimen?\n> Die beiden Kandidaten ziehen sich zurueck. Nach 5 Minuten tritt der\n> Geistliche\n> vor das Publikum und stellt sein Werk vor:\n> "I was a father all my life,\n> I had no children, had no wife,\n> I read the bible through and through\n> on my way to Timbuktu..."\n> Das Publikum ist begeistert und waehnt den Kirchenmann bereits als den\n> sicheren Sieger.\n> Doch da tritt der australische Schafhirte vor und dichtet:\n> "When Tim and I to Brisbane went,\n> we met three ladies cheap to rent.\n> They were three and we were two,\n> so I booked one and Tim booked two..."\n>'
# 'UK war mein Fehler - die sample customers kan ich schlecht rauslassen....\n\n-----Ursprüngliche Nachricht-----'
# 'Das ist aber schade !\n\nAber wir haben unsere Treffen bisher schon so oft verschoben, da kommt es auf einmal mehr auch nicht\ndrauf an; ich hoffe aber, dass es nicht mehr ganz so lange dauert, bis es wirklich wieder klappt !\nBis bald hoffentlich\n\nebenfalls ganz liebe Gruesse\nWerner'
# 'Hallo ,\n\nsollen wir daran teilnehmen???'
# 'Hallo Werner\n\nwir haben längere Zeit nichts voneinander gehört. Ich wollte mal nachfragen\nob wir eine DemoVersion und eine Einweisung der Software haben können ?'
# 'Hallo Werner,\n\nanbei Infos zur Cebit.\nLog Dich doch bitte mal ein bei der SUN Aussteller Site (Kennwort etc. unten) und schau Dir mal die Auswahl für Cebit Hardware/ Equipment/ Internetverbindung etc. (also Tech-Stuff) an, und mach ein paar Recommendations. Ansprechpartner von Livingston Rental ist ein Herr Mäder.\nTel. 06151-9344303.\n\n\nChristian\n\n-----Ursprüngliche Nachricht-----'
# 'Das ist einfach nur brilliant...gibt es denn keinen unter Euch, der einen Lektor in einem guten Verlag kennt.\n\nViel Spass beim Lesen,\nStefan\n\n\n\n\n\n\nDas ist jetzt schon eine Weile her, aber ich erinnere mich als ob es gestern gewesen waer...  (von J. Schneider)\n\nRollerbleder\nWieder mal Wochenende. Ich hoppele mit meinen Blades in Malibu am Strand entlang. Nach 2 Jahren unfallfrei mein erster ungewollter Sturz. Peng. Sie versucht zu bremsen rast mir dann aber mit ihren Blades in die Rippen, verliert die Balance und faellt auf mich. Soviel Koerperkontakt hatte ich mir gar nicht erhofft.\n\nScheisse, eine Rippe tut richtig weh, wenn ich nicht immer soviel Gummisaft trinken wuerde waer die bestimmt gebrochen. Das naechste Mal lasse ich mich vor eine fallen, die langsamer bladed und was noch wichtiger ist, ich sollte VORHER checken ob sie einen Ehering anhat. Na ja, you live you learn. Als ich mich unter ihr rausschlaengele fragt sie mich als erstes :\n\n"Did you do that on purpose?".\n\nSauber, auf frischer Tat ertappt, darauf bin ich nicht gefasst und stottere sowas wie "Aeh yes, but it was a mistake, I didnt see your ring."\n\nDa sie eh verheiratet ist, wovor ich grossen Respekt habe, hab ich jetzt gar keine Hemmungen mehr und frag sie warum sie denn so jung geheiratet hat und ob wir noch ein bissi zusammen weiter bladen koennen. Sie guckt mich 10 lange Sekunden lang an. Dann sagt sie ohne zu laecheln, "You better stay behind me".\n\nWell well well, ich bin mir nicht ganz sicher ob das eine Einladung war oder nicht. Dem Gesichtsausdruck nach zu urteilen eher nicht aber sie hat ja gesagt ich soll hinter ihr bleiben also blade ich hinter ihr her, sie dreht sich nicht zu mir um. Nach einer Weile habe ich darauf keinen Bock mehr. Ich traue mich wieder naeher ran und frage sie ob sie Erste Hilfe und Mund-zu-Mundbeatmung kann. Sie gibt mir keine Antwort sondern sagt nur "Why?"\n\nIch: "Well, in case I fall again, it would be a comfort to know that there is somebody around to save me..."\n\nIm Moment wo ich es sag faellt mir auf dass das eine ziemlich bloede Anmache war. Na ja vielleicht hat sie es ja nicht bemerkt......Oh doch sie hat es gemerkt .... sie gibt mir einen unbeindruckt, gelangweilten Blick, sagt "Ha ha" und faengt auf einmal an wie wild Gas zu geben. Na, ja dann halt net, Lebbe geht weida. Zwei Sekunden spaeter bemerke ich, dass sie mir fehlt, und dass ich doch einigermassen emotionally attached war. Weitere 2 Sekunden spaeter beginne ich darueber nachzusinnen wie wir wohl unsere Kinder genannt haetten.\n\nUngefaehr 2 weitere Sekunden spaeter tut es einen Schlag der mich aus meinen Traeumen reisst. Sie ist in ihrem Eifer tatsaechlich mit voll Karacho in einen Sandhubbel reingebraust. Hier eine Nebenbemerkung: Malibu und Santa Monica nutzen meine Steuergelder nicht um den beach walk von Sand freizuhalten, nein sie bezahlen von meinen Steuergeldern die Politessen, die mir Knöllchen fuer 38 Dollar verpassen, weil ich nach Sonnenuntergang auf einem Parkplatz geparkt hab wo steht "from sunrise til sunset" (das Schild hab ich im Dunkeln nicht gesehen). Und selbst das Knoellchengeld wird nicht in Sandfegemaschinen angelegt, aber das ist eine andere Geschichte. Anyway, diesmal war es ja sogar fuer was gut, ich blade zu ihr hin und frage sie : "Are you OK?" Sie sagt irgendwas mit ihrem Elbow. Ich helfe ihr hoch und kann mir jetzt das Grinsen nicht mehr verbeissen, obwohl ihr rechter Arm an ihr runterhaengt als waere es ein schlecht angeklebtes Plastikteil und sie Schmerzen zu haben scheint frage ich sie grinsend\n\n"Did you do that on purpose?"\n\nJetzt grinst sie mich an...sie lacht sogar! Ich sage "You have to work on your falling-technique....I can give you lessons." Sie bladed vorsichtig los und haelt ihren Ellbogen...sie grinst immer noch. Ich: "Maybe I should take you to a doctor. I know a good doctor, his name is Dr. Brown. He is really good. I have only been here for 3 months but I learned already that in LA yo ...
# 'Hallo Herr Hehl,\n\nvielen Dank für Ihre Mühe, sieht wirklich super aus! Die Pocket-PC Variante\nist wirklich fantastisch geworden. Bei WAP ist das nict angezeigte Logo\nschade, Ich könnte mir vorstellen, dass es daran liegt, dass mein Server den\nMIME-Type wbmp nicht kennt. Kann man da was machen? z.B. das File auf einen\nanderen Server legen? Aber wie gesagt, ich würde auf WAP keine so grosse\nPriorität legen.\n\nEs tut mir leid zu hören, dass es in Ihrer Familie gesundheitliche Probleme\ngibt. Umso dankbarer sind wir natürlich für Ihren tollen Einsatz für unser\nkleines Schnellschuss-Projekt.\n\nNochmals herzlichen Dank und alles Gute, insbesondere für Ihre Frau'
# 'Sehr geehrter Herr xxx,\n\nWillkommen bei mamax. Ihre Registrierung war erfolgreich. Ihre Angaben wurden wie folgt gespeichert:\n\nIhr Benutzername lautet: xxx05101956\n\nFalls Sie das Passwort einmal vergessen, können Sie sich über die Antwort auf Ihre Sicherheitsfrage identifizieren.\n\nIhre Adresse haben wir wie folgt gespeichert:\nfixstring\n00000 fixstring\n\nViel Erfolg\n\n\nIhr mamax-Team\nhttp://www.mamax.com'
# ",\nI don't know as I don't support them technically. Will forward to  and Werner\n\n\n-----Ursprüngliche Nachricht-----"
# "Sehr geehrter Herr Schumann,\n\nda es sich hier um einen kostenlosen proof-of-concept handelt bitte ich um Ihr Verständnis, dass wir vorerst nicht alle weiteren Wünsche einbauen können. Wir können hier gerne optimieren, wenn wir weiter fortfahren.\n\nWenn ich Kapazität der Entwickler frei'schaufeln' kann, lasse ich das Logo morgen einbauen. Dies war allerdings Ihrerseits bislang nicht gefordert und nicht geliefert.\n\nDie Definition der Umleitungsseite ist Ihre Entscheidung. Ich schlage wap.mamax.de/com vor.\n\nMit den besten Grüssen\n\n Federer\n\n-----Ursprüngliche Nachricht-----"
# 'Sehr amüsant: Gibt es so etwas wirklich ???\n\n\n\n> Im Folgenden eine wahre Begebenheit - Ein Schriftwechsel, der zwischen\n> den Mitarbeitern eines Londoner Hotels und einem seiner Gäste hin- und\n> herging.\n> Das betroffene Hotel überließ diese Korrespondenz der Sunday Times. Es\n> wurden selbstverständlich bei der Veröffentlichung keine Namen genannt.\n>\n>\n>\n>\n>  Sehr geehrtes Zimmermädchen,\n>\n> ich möchte Sie bitten, keine dieser kleinen Seifenstückchen mehr in\n> meine Badezimmer zurückzulassen, weil ich ein großes Stück meiner\n> eigenen Lieblingsseife (Dial) mitgebracht habe. Bitte entfernen Sie die\n> sechs ungeöffneten kleinen Seifenstücke von der Ablage unter dem\n> Medizinschränkchen, ebenso wie die drei weiteren Stücke aus der\n> Seifenschale in der Dusche - sie stören mich.\n>\n>  Danke. S. Berman\n>  _________________________________\n>\n>  Sehr geehrter Gast in Zimmer 635,\n>\n> ich bin sonst nicht für Ihr Zimmer zuständig, und meine Kollegin wird\n> morgen,am Donnerstag, wieder hier sein. Ich habe wie gewünscht die 3\n> Hotelseifen aus der Seifenschale in der Dusche genommen. Die 6 Seifen\n> auf der Ablage habe ich weggeräumt und auf die Oberseite Ihres\n> Papiertuchbehälters gelegt, falls Sie es sich anders überlegen sollten.\n> Ich hoffe, daß dies zu Ihrer Zufriedenheit ist.\n>\n> Katrin, Aushilfszimmermädchen\n>\n> ________________________________\n>\n> Sehr geehrtes Zimmermädchen - ich hoffe, daß Sie mein reguläres\n> Zimmermädchen sind, anscheinend hat Katrin Ihnen nichts von meiner\n> Nachricht über die kleinen Seifenstücke erzählt. Als ich heute abend in\n> mein Zimmer zurückkam, stellte ich fest, daß Sie 3 weitere Stückchen\n> Camay-Seife zu den\n> Stücken auf der Ablage unter meinem Medizinschrank gelegt hatten. Ich\n> werde zwei Wochen lang hier im Hotel sein und ich habe meine eigene\n> große Seife\n>  mitgebracht. Ich werden also diese 6 kleinen Camay-Seifen auf der\n> Ablage nicht benötigen. Sie stören mich beim Rasieren, Zähneputzen usw.\n> Bitte entfernen Sie sie.\n>\n>  S. Berman\n>\n>  ________________________________\n>\n>  Sehr geehrter Herr Berman,\n>  am Mittwoch hatte ich meinen freien Tag und meine Kollegin hat 3\n> Hotelseifen in Ihr Badezimmer gelegt. Wir sind vom Management\n> angewiesen, das so zu machen. Ich habe die 6 Seifenstücke, die Ihnen im\n> Weg waren, von der Ablage\n>  weggenommen und habe sie in die Seifenschale gelegt, wo Ihre\n> Dial-Badeseife war. Die Dial-Seife habe ich in Ihren Medizinschrank\n> gelegt. Ich habe die 3 Hotelseifen nicht aus dem Medizinschränkchen\n> genommen, die sind immer für neue Gäste da und Sie haben darüber nichts\n> gesagt, als Sie am letzten Montag ankamen. Bitte teilen Sie mir mit,\n> wenn ich Ihnen weiter behilflich sein kann.\n>\n> Ihr reguläres Zimmermädchen, Annette\n>\n>  ___________________________________\n>\n>  Sehr geehrter Herr Berman,\n>\n> Herr Kramer, unser stellvertretender Manager, hat mich darüber\n> informiert, daß Sie ihn gestern abend anriefen und ihm mitteilten, daß\n> Sie mit unserem Zimmermädchen-Service unzufrieden sind. Ich habe ein\n> neues Mädchen eingeteilt,das jetzt für Ihr Zimmer zuständig sein wird.\n> Ich möchte mich für alle Ihnen entstandenen Unannehmlichkeiten\n> entschuldigen. Sollten Sie weitere Beschwerden haben, setzen Sie sich\n> bitte mit mir in Verbindung, damit ich mich persönlich darum kümmern\n> kann. Sie erreichen mich unter 1108 zwischen 8.00 und 17.00 Uhr.\n> Danke.\n>\n> Elisabeth Möller, Haushälterin\n>\n>  ___________________________________\n>\n>  Sehr geehrte Frau Möller,\n>\n> es ist nicht möglich, telefonisch mit Ihnen in Verbindung zu treten,\n> weil ich in geschäftlichen Angelegenheiten das Hotel um 7.45 Uhr\n> verlasse und nicht vor 17.30 oder 18.00 Uhr zurückkomme. Aus diesem\n> Grund habe ich gestern Abend Herrn Kramer angerufen. Sie waren nicht\n> mehr im Dienst. Ich habe Herrn Kramer nur gefragt, ob er irgend etwas\n> gegen die kleinen Seifenstückchen unternehmen könnte. Das  ...
# "Servus Feile!\n\n\n\nDienstag Mittag schaut gut aus - werde Werner mal diesbezüglich fragen.\n\nWie kann ich dich denn erreichen? Gibt's dein Handy noch?\n\nUli.\n\n\n__o\n`\\<,\n(*)/(*)\n..........................................................\n>\n>Hallo Uli,\n>\n>Bin auch gerade im Ruhestand. Plane gerade unseren\n>Urlaub (Italien: Toskana-Umbrien). Wenn alles gut\n>geht moechte ich in der Woche zum 20ten weg.\n>\n>Mittagessen hoert sich gut an. Vielleicht Dienstag?\n>Habe moeglicherweise einen Termin um 16:45 am\n>Flughafen. Muss das also noch abklaeren. Wie sieht's\n>den mit Werner aus.?\n>"
# ',\nbefore the conf call starts: any infos from the board meeting?\n\nP.\n\n-----Ursprüngliche Nachricht-----'
# 'Sehr geehrter Herr Mueller,\n\nAuch ich bedanke mich für das vorherige Gespräch und hoffe auf eine erfolgreiche Zusammenarbeit in der Zukunft. Wie vereinbart, erhalten Sie eine erste Übersicht unserer Technologie-Platform. Ich hoffe, diese Informationen sind hilfreich für Ihre Analyse und freue mich auf den nächsten Kontakt.\n\nmit fruendlichen Grüssen,\n\nRené Romain'
# '" Federer" <.Federer@avocadoit.com>,\n"Ulli Eder" <Ulli.Eder@avocadoit.com>,\n"Katja Holtkamp" <kholtkamp@avocadoit.com>,\n"Christoph Wicharz \\(E-Mail\\)" <christoph.wicharz@avocadoit.com>,\n"Juliana" <Juliana.King@avocadoit-uk.com>'
# '17, 2001) at 27.06.2001 08:50:45\nHallo Werner,\n\nBesten Dank fuer Deine Antwort. Der Passthrough funktioniert bestens!'
# 'Sorry - this is increadible!\n\n-----Ursprüngliche Nachricht-----'
# 'Sehr geehrter Herr Schlegel,\n\nanbie übersenden wir Ihnen eine Anfahrtsskizze.\n\nWir wünschen Ihnen eine gute Anreise.'
# ',\nsorry - the attachment was missing.\n\n\n\n-----Ursprüngliche Nachricht-----'
# 'Rene,\n\nDenkst Du bitte an einen deutschen Arbeitsvertragstext auf Floppy. Ich treffe Do und Fr Kandidaten.\n\nDanke & bis Morgen'
# 'Werner,\n\nversuche bitte, die LH4132 MUC ab 10:50, Nice an 12:20 zu erreichen. Business Class ok wenn notwendig. Zurück am Donnerstag spätnachmittag LH5747 (15:45) oder LH5731 (21:25 - gönne Dir wenigstens einen Fisch in Nizza)). In allen drei Flügen sind Business Class Sitze frei. Nur zur Abstimmung: am Freitag klärst Du technische Fragen mit Diebold wegen des T-Mobile Besuchs in den USA...\n\nDein Kontakt in Sophia ist:\n\nFlorence Dubois          phone +33 (0) 4 92 94 17 18\nAccenture - Technology   mobile +33 (0) 6 71 60 36 82\nResearch & Innovation    e-mail\nBP 99 Les Genets         florence.dubois@accenture.com\n449 route des Cretes\n06902 Sophia Antipolis -\nFRANCE\n\nEin Mail über die Probleme ist an Dich gegangen. Summarisch sagt Accenture:\n"Rolf has been trying to render pages from the Cobra Release 1, but there\nwas no success. He had the support of Simone.\nThe main issues encountered are due to the cookies (persistent and session)\nwe have in our pages. We are not even able to render the first page, the\nlogin process. Also some HTML pages are created from Siebel, and we get the\nsame type of issues. Most of the time when we load a page in the design\nstudio, the application crashes, and we have to start all over again. That\nis becoming critical as we are supposed to have R2 delivered by the end of\nJuly. The alternative we have if we cannot use AvocadoIT successfully is to\nbuild ourselves the WML pages (in JSP as for the HTML pages in R1)"\n\n\nDas ist der Gesamtplan:\n\nAfter our discussions:'
# 'Dann bin ich es wenigstens nicht, sondern das Sch... System, was die sich da angelacht haben.\n\n\n\n-----Ursprüngliche Nachricht-----'
# '(Thijs); . Federer; Ulli Eder\nSubject: Fw: Revised messaging\n\n\nHi,\n\nTo please review the attached document - I need AY comments you may have by\nEnd of Play Tuesday 6th Feb.\n\nThanks'
# "Hallo Norbert,\n\nnach laengerer Zeit moechte ich mich wieder 'mal bei Dir melden;\nes gibt auch etwas Neues zu berichten - nachdem ich von einer\namerikanischen Startup-Company ein interessantes Angebot\nbekommen habe, habe ich mich entschlossen, SGI zu verlassen\nund ganz etwas Anderes zu probieren; die Firma ist im Wireless-Business\ntaetig und hat jetzt in Muenchen ein Buero eroeffnet; zur Zeit\nsind wir hier 2 Personen, das ist ganz witzig;\nich gebe Dir 'mal Telefon und Email-Adresse:\nAvocadoIT Europe\nTel.:     089 / 35874311\nEmail:  wernerh@avocadoit.com\n\nnachdem es mit dem Biergartentermin wieder nicht geklappt hat, koennen\nwir ja mal einen Kneipentermin in naechster Zukunft ins Auge fassen"
# 'Hallo Werner, wollte mal wissen wie es dir geht. Ich ziehe diese Woche im\nAmt um und habe dann eine neue Durchwahl Tel. 0821/3151-277! Montag richte\nich mich in meinem neuen Zimmer bis 10.00 Uhr dann ein und am Dienstag ist\nfür drei Wochen mein letzter Arbeitstag (nur Vormittag). Mit Anke werde ich\nam 27.08.01 für eine Woche in die Pfalz fahren und das wars dann. Der Rest\nist Badeseen u.ä. zu Hause. So long, lass mal was von dir hören!!! Marita'
# 'Mit  kann man reden, der macht das bestimmt (sofern sein Chef nichts dagegen hat)\nWerner'
# 'Hallo Werner,\n\nkönntest du hier dabei sein? Ich denke eine Demo wäre ganz passend.\nDie Leute sind von einem Siemens spinnoff... ;-)\n\nDanke,\nUli.\n\n-----Ursprüngliche Nachricht-----'
# 'Betty,\nthanks. Please bcc: me on your answer to him so we are in the loop the project may pop up in Europe.\n\n\n\n-----Ursprüngliche Nachricht-----'
# '> Ute, Rolf,\n>\n>  gerade hat mich ein alter Kollege aus meinen SGI Zeiten angerufen. Er\n> arbeitet jetzt bei AvocadoIT (www.avocadoit.com) und ist dort fuer\n> Softwareentwicklung zustaendig. Anscheinend hat seine Firma einen Kunden,\n> der das AvocadoIT Produkt auf unserm IPAQ einsetzen will. Koennte etwas\n> groesseres sein.\n>\n>  Jetz braucht der Werner Hehl (Werner.Hehl@avocadoit.com) einen\n> technischen Kontakt um einige Dinge abzuklaeren. Kann einer von euch da\n> bitte eine Verbindung herstellen und mich auf dem laufenden halten? Werner\n> ist die naechsten 10 Tage in den Staten, solle aber e-mail lesen.\n>\n> Danke\n> Martin\n> ------------------------------------------------------------\n> Martin Knoblauch\n> HPTC Consultant, ESSG/HPSD\n> Compaq Computer GmbH\n> Dornacherstraße 3c, D-85622 Feldkirchen, Germany\n> Phone: +int 89 9591-2543, Fax: -1010-12543 (please include name)\n> Mobile: +int 171 8033 948\n> E-Mail: Martin.Knoblauch@Compaq.com\n>\n>'
# 'Hallo Werner,\n\nkannst Du mir eine Antwort auf die Fragen geben?'
# '" Westbrook" <.westbrook@avocadoit-uk.com>,\n"Darren Stribling" <darren_stribling@hotmail.com>,\n"Elizabeth Holder" <elizabeth.holder@avocadoit-uk.com>,\n"James Noble" <james@avocadoit-uk.com>,\n"Juliana King" <juliana.king@avocadoit-uk.com>,\n" Nunn" <.nunn@avocadoit-uk.com>,\n"Paul Danter" <paul.danter@avocadoit-uk.com>,\n"Robert Parker" <robert.parker@avocadoit-uk.com>,\n"Christoph Wicharz" <christoph.wicharz@avocadoit.com>,\n"Katja Holtkamp" <katja.holtkamp@avocadoit.com>,\n" Federer" <.federer@avocadoit.com>,\n"Ulli Eder" <ulli.eder@avocadoit.com>,\n"Werner Hehl" <Werner.Hehl@avocadoit.com>'
# 'Werner,\nkannst Du als Gag etwas von www.chavan.de mobilisieren?\n\n\n\n-----Ursprüngliche Nachricht-----'
# 'Hallo Alex,\n\nich bin gerade dabei, den Server etwas umzubauen; kannst Du\nmir bitte kurz mitteilen, welche Applikationen Du wie aufrufst ?\n(http://131......)\n\nDanke und viele Gruesse\nWerner'
# "Hi Toni,\n\nI'll try to put something together before the 17th!\n & nice day\n\nUli.\n\n-----Ursprüngliche Nachricht-----"
# 'Sehr geehrter Herr Bunn,\n\nwie steht es mit dem\nFirmenkatalog in CD-Rom Format.\nSteht dort  .com  oder  .de  ?\n\nMfG\n\nSchlegel\n\n\n\n\n-----Ursprüngliche Nachricht-----'
# 'I would say  Federer.  Another reason to do this is that they are 9 hours ahead and it would be near impossible for us to get in touch with them from here...'
# 'Hallo Ihr Lieben,\n\ngestern war ich in London und habe erfahren, dass ich morgen\nfuer 7-10 Tage nach Santa Clara fliegen muss; also muss ich\nwieder einmal absagen, aber das wird schon noch ... !\nIch melde mich, wenn ich wieder im Lande bin\n\nciao\nWerner'
# 'Metadesign AG\nHerrn Charly Frech\nBergmannstr. 102\n\n10961 Berlin'
# 'Es handelt sich um Dialogika, die mehrere Projekte haben (in D und LUX). Präsentation/Workshop geht an eine gemischte Truppe aus Entwicklern und VB (um letztere kümmere ich mich).\n\ncu\n\n\n\n-----Ursprüngliche Nachricht-----'
# 'Hi ,\n\nGreat - thank you!\n\nUli.\n\n-----Ursprüngliche Nachricht-----'
# '" Federer" <.Federer@avocadoit.com>, "Rdemms" <Rdemms@aol.com>'
# 'Diese Nachricht enthält Zeichen, die vom Internet-Dienst nicht unterstützt werden. Zum Lesen doppelklicken Sie auf die beigefügte Anlage. Falls der Text inkorrekt angezeigt wird, speichern Sie die Anlage (Datei, Speichern unter) auf der Festplatte und öffnen Sie sie mit einem Programm, das die Zeichen darstellen kann.'
# "Wird gemacht,  !\nIch wuensch' Dir eine schoene Woche !\n\nCiao\nWerner"
# '<.Federer@avocadoit.com>'
# 'Guten Morgen Frau Tillich,\n\nich habe Ihnen vor über 2 Wochen ein Formular von Herrn Hehl zugeschickt.\nEs handelt sich hier um die Hinterbliebenenrente. Ist das Formular\nIhrerseits\nschon bearbeitet. Herr Hehl benötigt die Unterlagen dringend.'
# 'Sender: listserv@globetrotter.de\nList-Help: <http://www.globetrotter.de/de/htm_serv/serv_new.php3>\nList-Unsubscribe: <http://globetrotter.de/us.php?e=werner.hehl@avocadoit.com>\nSie sind mit folgender E-Mail-Adresse an diesem Newsletter angemeldet:\nwerner.hehl@avocadoit.com\nHinweise zum Abmelden finden Sie am Ende dieses Newsletters.\n\n\nGlobeNews Januar 2002\n\nLiebe Kundinnen und Kunden,\nauf die Plätze, fertig ... los - mit dem ersten Newsletter des Jahres startet\nGlobetrotter Ausrüstung mit starkem Inhalt in ein erneut vielversprechendes\nneues Jahr: die Produktion des kommenden Handbuchs läuft auf Hochtouren -\nunsere Redaktion schiebt Sonderschichten, das Fotostudio blitzt Tag und\nNacht. Exklusiv für Sie als Abonnent verraten wir Ihnen schon jetzt die\nheißesten Produkte des Jahres. Herzlich Willkommen bei den GlobeNews\n2002. Und den gewohnt unschlagbaren Sonderaktionen ...\n\nDie große Jack Wolfskin Sonderaktion\nJack Wolfskin räumt auf - und  hat uns diesen stattlichen Sonderposten zum\nFreundschaftspreis zur Verfügung gestellt. Wer für frostiges Schlittschuh-\nWetter nicht das richtige fand, sollte jetzt aufhorchen: hier gibt\'s für kleines\nGeld erstklassige Qualität: winddichtes Stormlock, dickes Polartec und feines\nTecnopile, aber auch einige leichte Sachen (für die, die sich aus Eishockey und\nPirouetten nichts machen und lieber ins Warme entschwinden). Was halten Sie\nz. B. vom Metropolitan Jacket für nur 119,95 EUR (statt 204,47 EUR) via\nhttp://www.globetrotter.de/go2link.php?link_id=020101 ; dem warmen Denali\nJacket für nur 249,95 EUR (statt 460,11 EUR) via\nhttp://www.globetrotter.de/go2link.php?link_id=020102 ; dem Rolling Stone\nDaypack für nur 119,95 EUR (statt 204,47 EUR) via\nhttp://www.globetrotter.de/go2link.php?link_id=020103 ; oder, oder, oder. Die\ngesamte Sonderaktion finden Sie hier:\nhttp://www.globetrotter.de/go2link.php?link_id=020104 . Viel Spaß beim\nShoppen!\n\nPatagonia Sonderaktion\nWer bei den z. Zt. frostigen Temperaturen doch noch auf den Geschmack\neines zünftigen Schneeurlaubs kommt, hat hier die Chance seine alten\nSkisachen durch ein flottes Schnäppchen zu ersetzen: Patagonia räumt raus,\nwas aus der Saison noch übrig ist! Flauschige Fleecepullover, bequeme\nJacken oder funktionelle Skihosen. Hier ein paar Beispiele: der Synchilla Snap-\nT Pullover via http://www.globetrotter.de/go2link.php?link_id=020105 und nur\n49,95 EUR (statt 102,21 EUR), das Flux-Jacket via\nhttp://www.globetrotter.de/de/htm_shop/detail.php3?artnr=qz-40-402 (men) und\nhttp://www.globetrotter.de/go2link.php?link_id=020106 (women) für nur 149,95\nEUR (statt 296,50 EUR) oder die Fall Line Pants via\nhttp://www.globetrotter.de/go2link.php?link_id=020107 für nur 149,95 EUR\n(statt 322,06 EUR). Damit können Sie warm eingepackt und vor feuchtem\nSchnee und Wind geschützt zur nächsten Tour starten. Die komplette Aktion\nfinden Sie hier: http://www.globetrotter.de/go2link.php?link_id=020108 .\n\nPatagonia - in der stürmischsten Ecke der Erde\nBy the way: mit einem Fahrrad-Reisebericht aus Patagonien haben Andreas\nvon Heßberg und Waltraud Schulze eine spannende und sehr informative\nHomepage aufgebaut. „Wenn du dich nicht am Lenker festhältst, weht es dich\nrunter" schreiben Sie am Anfang ihrer (auch als PDF-Download)\nunterhaltsamen Zeilen. Unbedingt mal reinschauen:\nhttp://www.globetrotter.de/go2link.php?link_id=020109 . Und viele weitere\nReiseberichte unter unserer Domain http://www.reiseberichte.com\n\nAus dem Handbuch 2002: Willkommen in der Matrix\nEagle Creek präsentiert mit dem Matrix Titanium ein reinrassiges Daypack für\nMusikfans. Und ist mit dem gepolsterten Fach für CD-Player (Handys etc.),\neinem Ausgang für Kopfhörerkabel und shockabsorbierenden Schultergurten\nunschlagbar für den Musikgenuss in der City.  Weitere Infos finden Sie schon\nhier: http://www.globetrotter.de/go2link.php?link_id=020110 . Und natürlich bald\nbei Globetrotter Ausrüstung.\n\nDie Ajungilak Sonderaktion\nNoch begrenzt  ...
# 'falls Du es nicht hast\n-----Ursprüngliche Nachricht-----'
# 'Werner,\nbei mir lautet die Userid dac1703676@uudial.de, scau mal auf der uunet.de seite unter support, die haben zum 1.10 irgendwas geändert...\n\n\n\n-----Ursprüngliche Nachricht-----'
# "Christian,\nbitte Christoph's Frau anrufen.Katjas Adresse anbei:\nHoltkamp, Katja\nPaffendorfer Weg 38a\n50126 Bergheim\nGesch. 1: +49 (175) 2238686\nPrivat: +49 (2271) 498297\nE-Mail: holtkamp-streicher1@otelo-online.de"
# "Schau Dir mal www.handykult.de an. Dort gibt es zu jedem Hersteller Foren\nüber Fehler etc. Natürlich posted dort die Freaks, also laß' Dich nicht\nentmutigen... ;-))"
# "Die U-Bahn kam ziemlich schnell, um Punkt 12 war ich schon zu\nHause - dafuer habe ich heute bis 8 Uhr geschlafen (wahrscheinlich\nwarst Du um diese Zeit schon fleissig !)\n\nich wuensch' Dir einen schoenen Tag - und arbeite nicht gar so viel !\nCiao\nWerner"
# 'Hi Werner!\n\nHast du dazu schon was erhalten?'
# 'Guten Morgen Uli,\n\nbin gerade am überarbeiten der Folien ... !\nhierzu noch eine Fragen:'
# 'Hallo ,\n\nnochmals Danke für die Tips.\n\nWenn Sie mal ein paar Minuten Zeit haben, können Sie die Hochzeitsbilder von Ayako und mir unter\n\nhttp://members.tripod.de/aics/ayakochristian1/index.html\n\nanschauen\n\nViel Spaß\n\nChristian\n______________________________________________________________________________\nSie surfen im Internet statt im Meer? Selbst schuld!\nAuf zum Strand: http://lastminute.de/?PP=1-0-100-105-1'
# "Hallo Guenter,\n\nauf meiner Eintrittskarte steht folgendes drauf:\n23. Juli  20.00\nUnterrang 203\nEingang Nord\nReihe 15\nPlatz 19\n\nhoffentlich gibt's noch Karten\n\nciao\nWerner\n\nPS: ansonsten regnet's hier immer noch ..."
# 'Hi Virpi,\n\nVielleicht ist dieses "attached" announcement der LBBW und Mobilcom für Andreas von Interesse, besonders vor sein Gespräch mit dem neuen Management. Leider habe ich nicht sein e-mail Addresse.'
# 'Hallo Ulli,\nIch habe erst freitag nachmitag die nachricht von rene bekommen. Die mangelhafte fuhrung unsere firma ist wirklich eine schande - hoffentlich haben sie sich besser behandlet bei dir als wir bei rene.  Ich schatze ab mitwoche wurde ich auch nach eine neue stelle schauen mussen - hier in amerika mussen auch leute entlassen werden u wahrend meine "gute" bezieung mit mein neuer chef bin ich sicher dabei.\nAlles bestens Ulli u bleib in kontact - mein handy nummer wurde sich nicht andern u ich bin immer an ronds@hotmail.com zu erreichen.\n\nPs veilleicht sehen wir einander zum oktoberfest - ich muss es endlich mal besuchen u dieses jahkommt es daran. (www.avocadoit.com)'
# 'Guten Morgen, Regine,\n\nmerci fuer einen schoenen Abend !\n\nCiao\nWerner'
# 'Hallo Frau Leschik-Weiler,\n\nanbei schicke ich Ihnen drei Word-Dateien (tabellarischer Lebenslauf, kurzes Leistungsprofil,\neinige Projekte);\nsollten Sie noch weitergehende Informationen benoetigen, so lassen Sie es mich bitte wissen;\n\nich wuensche Ihnen ein schoenes langes Wochenende,\nmit freundlichen Gruessen\n\nWerner Hehl'
# 'Uli,\nwas sollen die installiert bekommen? Für wie lange? Auf welchem\nEquipment?Wer darf da dran? Wer supportet? Wie schnell? Müssen die es uns\ndsagen, wenn die demonstrieren? Können die überhaupt demonstrieren? Oder\nwerden die trainiert? Von wem?\n\nFie Firma gibt das Design Stuio nur sehr ungern raus. Kann ich auch\nverstehen. Umso genauer die Vorbereitung.'
# 'Sehr geehrter Herr Federer,\nendlich habe ich die beiden Kollegen, die an dem Rendering-Tool-"Workshop" teilnehmen sollen, "unter einen Hut gebracht". Als Termine sind dabei herausgekommen:\nentweder Mo., den 22.1.01 oder ein beliebiger Tag Mo. bis Do. der Folgewoche (29.1.-1.2.).'
# 'Hallo Fr. Eder,\nich würde am 19.01. mit H. Christof Schwab, Head of Strategie und Partner Management,\num 9 Uhr bei Ihnen vorbei kommen. Wir planen ca. 2 Std. für das Gespräch ein.\n\nFreue mich auf das Meeting.'
# 'Also bitte Changes etc an mich Donnerstag\n\n-----Ursprüngliche Nachricht-----'
# '"Christoph. Wicharz" <christoph.wicharz@avocadoit.com>,\n"Kumi Thiruchelvam" <kumi@avocadoit.com>,\n"Mark Stadhouders" <mark@stadhouders.com>,\n"Matthew van Gessel (Thijs)" <thijs.van.gessel@avocadoit-uk.com>,\n". Federer" <.Federer@avocadoit.com>,\n"Rene Romain" <rromain@avocadoit.com>,\n"Ulli Eder" <Ulli.Eder@avocadoit.com>'
# 'Und, was meinst?\n\nSollen wir das machen? Bräuchten aber zeimlich günstige Lösung (Start Up)\n\nUli.\n\n-----Ursprüngliche Nachricht-----'
# "Das ist doch mal 'was richtig Schoenes !\n\nWerner"
# '9.7\tUli, was immer wir beide bequatschen wollen,\nvielleicht noch Rene (wir kaspern sein Zeugnis\naus, sonst klappt das ja doch nie)\n13.7\t11.00 Diebold, dann schaun mer mal\n16.7\tFriendlyway zusammen mit Dir. Holst Du mich wieder an der S-Bahn ab?'
# 'Hallo Herr Romain,\n\nich habe u. a. die Lohnsteuerkarte eines Herrn Deinzer erhalten.\n\nIn der Anlage habe ich den Personalfragebogen beigefügt. Bitte geben Sie uns dann auch noch Eintrittsdatum und Telefonnummer bekannt für Rückfragen direkt an Herrn Deinzer sowie den Arbeitsvertrag.'
# 'Hallo Herr Hehl,\n\nleider funktioniert die angegebene URL\nhttp://131.99.72.21:8080/servlet/EPServlet?opt=dialogika nicht. (Die Seite\nwird nicht gefunden)'
# "Hallo Marita,\n\nvielen Dank fuer das tolle Fruehstueck ! Es war sehr schoen, Dich\nwiederzusehen;\n\nich wuensch' Dir ein schoenes Wochenende\nWerner"
# 'Merci jedenfalls !'
# 'Hallo Rolf,\n\nkannst Du mir bitte noch die home.aml Datei schicken ?\n\nMerci\nWerner'
# 'Mon Dieu - Asche auf mein Haupt !'
# 'Sehr geehrte Damen und Herren,\n\nwir, die AvocadoIT Europe GmbH, bieten Mobile Solutions an, die jedwedes HTML Format (Internet, Extranet, Intranet) in die verschiedenen Mobile Devices (Handy, PDA, pagers etc.) umsetzen kann. Dabei setzen wir weder auf seperate Serverhaltung, noch auf seperate Gerne würde ich dem LTU Mitarbeiter der verantwortlich für Internet, und speziell mobiles Internet (allgemein: mobile Anwendungen), unsere Firma und unsere Technologie näher vorstellen, weshalb ich Ihnen sehr dankbar wäre, wenn Sie mir freundlicherweise Name, Anschrift, Durchwahl des Ansprechpartners zurück-mailen/-schreiben/-rufen könnten.\n\nFür Ihre Aufmerksamkeit und Bemühung bedanke ich mich.'
# 'Glen,\nsorry I missed the meeting, talking to finance.\n\n\n\n-----Ursprüngliche Nachricht-----'
# 'Ajay,\nhow are you today - jet lagged?\n\n\n\n-----Ursprüngliche Nachricht-----'
# 'Es ist unterwegs mit der Post.\n\nMfG. René Romain'
# 'Hallo Werner,\n\nwie sieht es am Samstag aus mit Spaghettiessen ? Diese Woche ist ziemlich\nchaotisch, da würde mir der Sonnabend besser passen als Freitag.'
# 'wolfi@sgi.com\nHallo Zusammen,\n\nbin momentan ziemlich beschaeftigt und daher\nleider nicht da.\n\nTrotzdem auf diesem Wege liebe Gruesse,\n\nThomas - The Terminator\n\n--- Thomas  Meier <thmcu@web.de> wrote:\n> Bin unterwegs und kann leider nicht kommen.\n> Viel Spass beim Ratschen!\n>\n> Bis denne mal wieder.'
# 'Sehr geehrter Herr Federer,\n\nich kann den Fehler jetzt nicht mehr nachvollziehen, er tritt nicht mehr\nauf.'
# 'Hast Du den 4.0 in gezippter Form? Dann mail ihn mir bitte. Ich hatte den bei Infospace, aber vergessen, mitzunehmen :-)'
# 'Guten Tag Herr Veraldi,\n\nsicherlich haben Sie es schon gehört: Das japanische i-Mode kommt nach Deutschland. (Lesen Sie hierzu z.B. folgenden Artikel: "KPN Mobile, TIM und NTT DoCoMo bringen i-mode nach Europa", http://www.golem.de/0101/11803.html)\n\nDies wird neben der WML-Sprache, dann auch cHTML Sprache erforderlich machen. Das Intelligent Rendering Tool von AvocadoIT ist in der Lage HTML-Am 2. Februar bin ich auf Geschäftsreise in Berlin. Ich würde mich sehr freuen, wenn Sie ein Stündchen Zeit für mich hätten, entweder am 1. oder am 2. Februar (jeweils nachmittags) um zukünftige mobile internet Szenarien zu besprechen und um die Lösungen von AvocadoIT vorzustellen.'
# 'Hallo Herr Messerschmidt,\n\nmir wäre ein Termin di-mi-do der Woche 29/1-1.2 sehr recht. Teilnehmer von\nunserer Seite wären Herr Hehl und ich. Vorraussichtlich brauchen wir Ihre\nHilfe für ein Hotel.\n\nMit besten Grüßen\n\n Federer\n-----Ursprüngliche Nachricht-----'
# 'Internetmagazin FirstSurf:\nDer woechentliche Newsletter am Montag, den 24.9.2001\nAnzahl der Abonnenten: 19.145\n\nHallo, liebe Web-Surferinnen und -Surfer.\nDie neue Ausgabe des Internetmagazins FirstSurf wurde soeben\nhochgeladen. Wir freuen uns auf Ihren Besuch:\nhttp://www.firstsurf.de\n\nDie Themen der Woche:\n\nTest: Sind Sie ein Erfindertyp?\nInternet: FTP-Zugang via WWW\nQuiz: Das grosse Team-Quiz - Mitraten und gewinnen\n\nMeldungen\n\nIm Ueberblick: Computervirus setzt neue Massstaebe\nTurbo: Surfen mit Breitbandanschluss ist "in"\nInternet-Inside: Das Netz auf dem Handy\nKaufrausch: Kostenloses E-Shopping\nGefuehlsbarometer: Keine Chance fuer Kraftausdruecke\nAufgeschoben: Bundestagswahl per Internet nicht in Sicht\n...\n\n--- HAUPTBEITRAG ---\n\nTest: Sind Sie ein Erfindertyp?\nNein, wir wollen nicht testen, ob Sie der zweite Daniel\nDuesentrieb sind. Es geht um Ihr kreatives Potenzial, finden Sie\nheraus, wie pfiffig Sie sind.\nhttp://www.firstsurf.de/eichenberg0139_f.htm\n\n--- HAUPTBEITRAG ---\n\nNetzige Software\nEine schnelle Aenderung an der eigenen Homepage? Unterwegs oder\nauch hinter einem Proxy-Server ist das ohne installierte\nFTP-Zugangssoftware kaum moeglich. Es sei denn, man bedient sich\nwww2ftp, einem komplett WWW-basierten FTP-Zugang, der diesen von\njedem Browser aus gestattet.\nhttp://www.firstsurf.de/webapp_f.htm\n\n--- GEWINN-QUIZ ---\n\nDas grosse Team-Quiz\nWas wissen Sie ueber Teamplayer, Leitwoelfe und Einzelkaempfer?\nRaten Sie mit und gewinnen Sie einen tollen Preis.\nhttp://www.firstsurf.de/wochenquiz\n\n--- ZAHL DER WOCHE ---\n\nWas klicken Fuehrungskraefte im Internet am liebsten an?\nhttp://www.firstsurf.de/index.htm#grafik\n\n--- ANZEIGE ----------------------------------------------------------\n\nAlles ueber Public Relations: wie Sie mit\nstrategischer Unternehmenskommunikation ihren\nErfolg steigern, Knowhow, Fallstudien, Tipps,\nLiteraturdatenbank, Seminarangebote und\ntagesaktuelle News im fuehrenden deutschen\nBranchendienst http://www.pr-guide.de. Mit kostenlosem\nNewsletter - gleich mal reinschauen!\n---  NEWS ---\n\nIm Ueberblick: Computervirus setzt neue Massstaebe\nSeine Gefaehrlichkeit ist unumstritten, auch wenn ein zuerst\nbefuerchteter terroristischer Hintergrund mittlerweile wohl\nausgeschlossen werden kann: Hintergruende und Fakten zu "Nimda",\ndem neuen und aussergewoehnlich aggressiven Computerwurm, im\nFirstSurf-Pressespiegel.\nhttp://www.firstsurf.de/news/09-24-01_f.htm\n\nTurbo: Surfen mit Breitbandanschluss ist "in"\nZwar hat uns die USA auch prozentual die Nase immer noch deutlich\nvoraus, aber auch bei uns waechst die Zahl der Surfer mit\nBreitbandanschluss stetig. 7,8 Prozent aller privaten Internetnutzer\nsetzen schon darauf.\nhttp://www.firstsurf.de/news/09-24-02_f.htm\n\nInternet-Inside: Das Netz auf dem Handy\nDie Internet-Inside-Technologie soll das Internet direkt auf das\nHandy bringen. Die Wissenschaftler des Fraunhofer Instituts haben\neine Technik entwickelt, die Nutzer gleichzeitig als Informationsquelle\n\nund Wissensspeicher nutzen koennen.\nhttp://www.firstsurf.de/news/09-24-03_f.htm\n\n--- ANZEIGE ----------------------------------------------------------\n\nWEBMASTER-UPGRADE: Skalieren Sie Ihr Know-how!\nmit Online-Workshops von akademie.de:\n\nPERL - Dynamische Webseiten mit CGIs in Perl:\nFormulare auswerten, Datenbanken abfragen...\nhttp://akademie.de/newsletter.php3/fs/workshops/perl.html\n\nFLASH 5 - Gestalten interaktiver Webseiten\nFlash-Filme, Tweenings, Aktionen, Schaltflaechen, Sound...\nhttp://akademie.de/newsletter.php3/fs/workshops/flash.html\n\nBezahlbar, kompetent und individuell betreut!\nKaufrausch: Kostenloses E-Shopping\nHauptgrund fuer den schleppenden Online-Verkauf sind die hohen\nEinwahlgebuehren ueber das Internet. So die Ueberzeugung der\nBetreiber von Shopping0800. Deshalb sollen nicht die Kunden\nsondern die Online-Shops die Internetgebuehren fuer den Einkauf\nuebernehmen.\nhttp://www.firstsurf.de/news/09-24-04_f. ...
# 'Werner Hehl <Werner.Hehl@avocadoit.com>,\nThomas Feil <thomasf@munich.sgi.com>, Wolfgang Szoecs <wolfi@sgi.com>,\nRenate Fuchs <rfuchs@warburgpincus.com>,\n Ebner <dianae@munich.sgi.com>\n--- Sandra Adelberger <sandra@netapp.com> wrote:\n> Also ich habe den Termin fest eingeplant.\n> Ihr werdet mich doch jetzt nicht schmaehlich im Stich lassen.\n>\n> Wie Frau E. weiss nicht sicher. Als Organisator abspringen ist nicht\n> genehmigt.\n>'
# '........... danke ..... bin am rumrennen .... ich leite weiter'
# 'Rene,\nDu sagtest, ich solle dich erinnern. Was ich hiermit mache:'
# ',\n\nist dieses Powerpoint Dokument dasjenige, das Du suchst (vor allem wohl Slide 11) ?\n\nCiao\nWerner'
# "fyi aber vertraulich. das ist noch nicht der endstand: 'you are here, this week...'\n\n-----Ursprüngliche Nachricht-----"
# 'Der aktuelle com3-newsletter ist da! Vielen Dank für Ihre Anregungen zur letzten Ausgabe.\n\nFür weitere news können Sie übrigens auch auf unsere Homepage gehen – www.absatzwirtschaft.de.\n\nWenn Sie selber news haben, zögern Sie nicht, uns Ihre Meldung zuzusenden. Wie gehabt verlinken wir Sie in einen exklusiven Bereich unserer Homepage unter der Adresse:\n\nhttp://www.absatzwirtschaft.de/newsletter/asw3.html'
# 'mit Dr. Knirsch gesprochen. Hat seine Mannschaft noch nicht zusammentrommeln können. Meldet sich bei uns in KW 49.\n\nChristian\n\n-----Ursprüngliche Nachricht-----'
# 'fyi\n\n\nInternetberater: Pleiten, Fusionen, Übernahmen\nDie ehemals strahlenden Chefs der Multimedia-Agenturen haben ihre\nhochtrabenden Visionen in die Schublade gepackt. Die Börsenkurse sind\nim Keller, die Geschäfte laufen schlecht. Nur wenige werden die\nDurststrecke überstehen.\n\nVon Annegret Loges\n\n\nBerlin - Ein "Tal der Tränen" durchschreite die Branche derzeit, sagt\nPixelpark-Manager Thomas Mörsdorf. Vor einem Jahr hatte sein Chef\nPaulus Neef noch ganz anders geklungen: "Wir werden zum Marktführer\nder europäischen Internet-Industrie", tönte der deutsche\nInternet-König. Nach Europa sollte der amerikanische Markt dran sein.\nHeute ist klar: Die Pixels haben sich verhoben.\n\nBereits zum zweiten Mal in diesem Jahr musste Neef die Planzahlen\nnach unten korrigieren, Mehrheitsaktionär Bertelsmann drohte mit dem\nAusstieg. Die Allianz-Versicherung stornierte genervt einen\nGroßauftrag; die Agentur war ihr zu langsam. Jetzt geht der ehemals\nschillernde Star der deutschen Gründerszene wieder Klinkenputzen bei\ninstitutionellen Anlegern, um dem Kurs der Pixelpark-Aktie auf die\nBeine zu helfen. Immerhin: Bei Roadshows in London und Frankfurt\ngelang es Neef, zwei große Investoren ins Boot zu holen.\n\nKunden aus Old Economy bleiben\n\nBei der Konkurrenz laufen die Geschäfte verhältnismäßig gut: Die\ngrößeren deutschen Internetberater wie Kabel New Media, GFT\nTechnologies oder I-D Media konnten sich dem allgemeinen Niedergang\nder New Economy bislang halbwegs entziehen. Umsatz und Gewinn sind\nnicht abrupt eingebrochen. Der Grund: Ihre Kunden stammen\nmehrheitlich aus der Old Economy. Doch die Aktienkurse der allesamt\nam Neuen Markt notierten Dienstleister sackten ins Bodenlose.\n\n"Es gab einen kurzen, absurden Augenblick, da waren unsere Aktien\nweniger wert als unser Cash-Bestand", sagt Bernd Kolb,\nVorstandsvorsitzender der Berliner Agentur I-D Media, deren Papiere\nbei fünf Euro dümpeln. Oliver Sinner, Chef von SinnerSchrader in\nHamburg, hat so gut wie resigniert: "Im Augenblick hat man gegen den\nTrend am Neuen Markt keine Chance."\n\nKonkurrenz von klassischen Beratern\n\nHinzu kommt, dass den jungen, dynamischen Internet-Experten\ninzwischen auch die klassischen Berater Konkurrenz machen.\nPricewaterhouseCoopers, KPMG und Accenture bieten jetzt ebenfalls\nInternet-Service aus einem Guss: von der Beratung über die Umsetzung\nbis hin zur weiteren Betreuung. Ein Glück, dass zumindest in\nDeutschland der Markt noch wächst.\n\n"Wir rechnen mit einem Wachstum für die Branche von 70 bis 80\nProzent", sagt Ulrich Dietz, Chef von GFT Technologies. Aber: "Die\nUnternehmen verlangen heute nicht nur Internetauftritte, sie wollen\nauch deren Verknüpfung mit dem eigentlichen Geschäft." Da ist ein so\ngenannter Frontend-Experte wie Pixelpark derzeit im Nachteil:\nSchließlich hat sich Paulus Neefs Agentur mit der Gestaltung von\nWebsites profiliert, nicht mit der mühsamen Integration des\nInternet-Auftritts in Geschäftsprozesse.\n\n"Die Branche ist noch nicht erwachsen"\n\nDie deutschen Multimedia-Berater haben nur eine Chance: Auch sie\nmüssen der Kundschaft Komplettlösungen anbieten. Dabei werden nach\nMeinung von Experten viele Agenturen auf der Strecke bleiben. "Mir\ngraut es immer, wenn vom Marktführer Pixelpark gesprochen wird", sagt\nSinner. "Pixelpark hat zwei oder drei Prozent vom Gesamtmarkt. Die\nBranche ist noch nicht erwachsen." Er tippt, dass die fünf Großen\nüberleben werden, wie in der klassischen Beratung.\n\nSarah Paulke von WestLB Panmure ist da weniger zuversichtlich. "Ich\nkönnte mir bei allen Agenturen Fusionen oder Übernahmen vorstellen",\nsagt die Analystin. "Pixelpark habe ich auf \'Sell\' stehen." Zwar habe\ndas Unternehmen einen starken Markennamen und gute Kunden, doch das\nGeschäftsmodell überzeuge sie nicht. GFT und I-D Media hätten jedoch\ngute Chancen, sich durch größere Zukäufe noch zu verstärken.\nNischenanbieter wie Antwerpes seien so klein, dass sie aufgekauft\nwerden könnten.\n\n"200-Ma ...
# 'Sehr geehrter Herr Schlegel,\nich werde Ihnen sobald als möglich einen terminvorschlag für anfang Februar übersenden.\nBis dahin verbleibe ich\n\nm f G\n\nJan Paulus\ndirector division broadband\n\nplenum New Media AG\nTorstrasse 134\n10119 Berlin\nTel.:+49.30.24088.0\nFax: +49.30.24088.500\njan.paulus@plenum.de\nhttp://www.plenum-new-media.com'
# "Einverstanden, treffen wir uns um 19.00 vor'm Kino ?\n\nWerner"
# 'Hallo , hallo Christian,\n\nich habe mit Herrn Wobberer von der Fa. Concept gesprochen und von ihm folgende\nInformationen erhalten:\nzur Zeit arbeitet Concept an der naechsten Version der Webpages fuer Mamax;\nfuer diese Version, die im Fruehjahr fertig sein soll, wird an der jetzigen Technologie -\nalso Javascripts ueber Frames, dynamische Pages usw. - nichts geaendert;\nerst nach Fertigstellung dieser Version kaeme - fruehestens ab Maerz - eventuell eine\nUmstellung der Technologie in Frage;\nauf die Frage, wie diese geaenderte Technologie - wenn sie ueberhaupt kommt - aussehen\nsoll, konnte Herr Wobberer keine Angaben machen; meiner Meinung nach hat sich\nnoch niemand bei Concept darueber Gedanken gemacht;\nes scheint also, als ob wir momentan mit dem aktuellen Format der Mamax Webseiten\nleben und hierfuer eine Mobilisierungsloesung finden muessten'
# ...
# 'Hallo Katja,\n\ndiese Frau Kruse ist telefonisch nicht erreichbar; ich habe ihr auch schon ein Mail geschickt,\naber es kommt keine Antwort\n\nciao und ein schoenes Wochenende\nWerner'
# 'hi LynchWu\ncan you please elabotare on the same....\nthanx\npaurnima'
# "Hi Rene,\n\nsorry, dass ich dich vorab nicht über diese Aktion informiert hatte.\nAber der Dr., Werner und ich hatten das gestern Nacht diskutiert\nund ich fand's eine sehr gute Idee an  direkt ranzugehen.\nIch hatte ihn ja in England kennengelernt und er hatte mir versprochen\nsich darum persönlich und so schnell wie möglich zu kümmern.\n\nEs ist tatsächlich gefährlich, wenn man ohne genau definierten\nVertrag als Freiberufler arbeitet. Das kann auch für mich eine hohe\nStrafe bedeuten.\n\nIch hoffe du hast damit kein Problem\n\nUli.\n\n\n\n-----Ursprüngliche Nachricht-----"
# "im Gegensatz zum normalem 'Arbeiten' in der Firma war ich am Wochenende\nrichtig produktiv: Staemme reissen, schneiden und hacken, Hecken schneiden,\nTrafo fuer elektrischen Zaun reparieren ... also alles, was Spass macht !\nEigentlich wollten meine Eltern mit nach Muenchen kommen, aber am Wochenende\nist eine Nachbarin gestorben, und da die Beerdigung erst am Dienstag sein wird,\nbin ich alleine zurueckgefahren;\n\nIhr muesst ja am Samstag ganz schoen heftig gefeiert haben, wenn Du noch\nam Montagmorgen muede bist ...\n\nciao\nWerner"
# 'Hallo Herr Messerschmidt,\n\nmir wäre ein Termin di-mi-do der Woche 29/1-1.2 sehr recht. Teilnehmer von unserer Seite wären Herr Hehl und ich. Vorraussichtlich brauchen wir Ihre Hilfe für ein Hotel.\n\nMit besten Grüßen\n\n Federer\n-----Ursprüngliche Nachricht-----'
# 'Das finde ich nett ....'
# 'Hallo Herr Prüfer,\n\nder NDA ist OK.Ich unterschreibe am Montag, wenn ich aus UK zurück bin. An welche postalische Adresse? Und wie geht es wann weiter?\n\nIn diesem Sinne mit besten Grüßen\n\n Federer'
# "Sehr geehrter Herr Becker,\n\nwie sieht die MOBILE INTERNET STRATEGIE von der DEAG aus?\n\nStellen Sie sich einmal vor,\n*\tdass Konzertkarten via mobilen Endgerät reserviert oder bestellt werden können, oder\n*\tdass per Mobilfunk oder PDA Informationen zu Ihrem Entertainment-Portfolio abgerufen werden können,  oder\n*\tdass allgemein alle zeitsensiblen Informationen jederzeit und überall abrufbar sind.\n\nDies sind unverzichtbare Servicebestandteile, welche Kundenbindung erhöht und Wettbewerbsvorteile sichert.\n\nDie Mobile Solutions von AvocadoIT decken diesen Teil der Wertschöpfungskette, und deshalb möchten wir uns in diesem Zusammenhang vorstellen.\n\nWir machen be-stehende HTML-Anwendungen (Intranet, Extranet, Internet) ‚mobil'. Und zwar unabhängig vom ver-wendeten Endgerät. Ohne getrennte Datenhaltung in WAP-, Palm-, xyz-Servern. Mit einer Sicht der Daten von allen mög-lichen Zugriffsarten aus, aber ohne diese Daten selbst zu speichern:\n\n\nSei es ein WAP-fähiges Telephon, ein Psion, ein Palm, ein ... oder was uns die End-ge-räte-in-dustrie (z.B. iMode) noch bringen mag - wir nehmen die Transaktion an, interagieren mit der bestehenden Anwendung und übermitteln deren aktuelle Resultate im richtigen Format an den Anforderer. Wir sind also gerade nicht auf den derzeit aktuellen WAP-Standard festgelegt, son-dern haben z.B. gerade in London (für die Tochter einer deutschen Bank)  einen Compaq PocketPC mit Internet Explorer so angepasst, dass die Informationen ohne Scrolling auf dem Bildschirm leicht ersichtlich verfügbar werden.\n\nWir können dies, weil wir die ursprüngliche HTML-Anwendung analysieren und dann deren Da-tengerüst als XML ablegen. Selbstverständlich kombiniert mit Ablauflogik in den üblichen For-ma-ten wie CGI oder Javascript.\n\nDer Vorteil liegt eindeutig in der vereinfachten und damit kostengünstigeren Abwicklung: unser Kunde pflegt weiterhin ‚nur' seine eigene Applikation, wir ver-binden auf welchem Weg auch immer, also 'Avocado IT', dessen Kunden unsichtbar für diese mit den gewünschten Anwen-dungen und Daten, indem wir die XML Strukturen mit aktuellen Daten füllen, auf das Endgeräte-format konvertieren und versenden.\n\nWir haben in den USA hierfür unter anderem schon Kunden aus dem Reisebereich (Travelbreak, Alaska Airlines), dem Finanzbereich (eTrade, Fidelity Investments Canada) und dem eCommerce (best buy).\n\nWir bieten diesen Service nun für Europa als Hosting in unserem IT-Center in England, aber auch als Hosting durch uns in Ihrem Rechenzentrum/Ihrem Server sowie ab Mitte 2001 auch als Lizenz an.\n\nIm Anhang finden Sie noch eine Kurzbroschüre.\n\nIch hoffe nunmehr, Ihr Interesse geweckt zu haben und würde mich über eine Aufforderung zur Einreichung weiterer Informationen, oder zur persönlichen Vorstellung unserer Lösungen in Ihrem Hause freuen. Ich erlaube mir, Sie in den nächsten Tagen noch einmal zu kontaktieren.\n\n\nMit freundlichen Grüssen aus Düsseldorf\nAvocadoIT Europe GmbH\n\n\n\n\nChristian Schlegel\nMarketing Leiter"
# 'Aber wir können beweisen, dass uns die Domain gehört, oder nicht ? Guter Punkt dass Dieses jedoch synchronisiert sein muss ...'
# "Hallo Herr Klawitter,\n\ndas Problem mit dem Logo scheint auf unserer Seite zu liegen;\nich schau', dass wir da noch etwas machen koennen, aber ich\nkann's Ihnen noch nicht versprechen;\n\nich moechte mich ganz herzlich fuer die guten Wuensche fuer meine\nFrau bedanken !"
# 'Herzlichen Dank !\nKoennten Sie mir bitte noch sagen, welchen Carrier\nSie nutzen (D1, D2, ...) ?\n\nWerner Hehl'
# "Hi,\n\ndie Teile haben Netzwerkkarte, Modem, Floppy-Laufwerk, CD-Laufwerk,\nsogar ein eingebautes Farbdisplay ist dabei ...\n\nich schau' mal, was die Amis sagen\n\nciao\nWerner"
# 'Hi Rene, nein leider kann ich deinen Bodo nicht öffnen. Schade. Rene, hast\ndu die email Adresse von Tania? Please transmit. Thank you . Have a nice\nweekend.\nBebe\n-----Ursprüngliche Nachricht-----'
# 'Sorry, vergass zu kopiere. FYI\n\n\n\n-----Ursprüngliche Nachricht-----'
# '> Sehr geehrter Herr Dr. Messerschmidt,\n>\n> Herr Federer hat mich gebeten, mit Ihnen Kontakt aufzunehmen bezueglich\n> eines etwaigen\n> Projektes mit der Regulierungsbehoerde; da ich hier noch ueber keine\n> weitere\n> Informationen\n> verfuege, moechte ich Sie gerne bitten, sich mit mir diesbezueglich in\n> Verbindung zu setzen;\n>\n> herzlichen Dank und viele Gruesse\n> Werner Hehl\n>\n>\n>\n> Werner Hehl\n> AvocadoIT Europe\n> Leopoldstr. 236/III\n> 80807 Muenchen\n> Tel.: 089 / 35874311'
# 'Subject: Mittwochs in der Grotte\n\n\nHi,\n\nwie sieht es diese Woche aus? Das Wetter muesste ja eigenlich fuer\ndraussen stimmen.\n\nMartin'
# 'Hallo Frau Kruse,\n\nFrau Holtkamp hat mich gebeten, Ihnen Screenshots der mamax-Applikation zu schicken;\nleider konnte ich Sie telefonisch nicht erreichen, um mich mit Ihnen abzusprechen, was\ngenau Sie braeuchten;\n\nvielleicht koennen Sie mich zurueckrufen;\n\nvielen Dank, mit freundlichen Gruessen\nWerner Hehl\n\n\n\nWerner Hehl\nAvocadoIT GmbH\nLeopoldstrasse 236/III\n80807 Muenchen\nTel: 089 / 35874311\n0174 / 9223508'
# 'Sehr geehrter Herr Federer,\nendlich habe ich die beiden Kollegen, die an dem Rendering-Tool-"Workshop"\nteilnehmen sollen, "unter einen Hut gebracht". Als Termine sind dabei\nherausgekommen:\nentweder Mo., den 22.1.01 oder ein beliebiger Tag Mo. bis Do. der Folgewoche\n(29.1.-1.2.).'
# 'Hervorhebungen von mir. Ansonsten fyi\n\n\n\n-----Ursprüngliche Nachricht-----'
# '<@avocadoit.com>, <.@avocadoit.com>,\n<.Braganza@avocadoit.com>, <mliang@avocadoit.com>,\n<NBodade@avocadoit.com>, <Yuyu.@avocadoit.com>,\n"Jesal Mehta" <JMEHTA@novell.com>,\n" Armstrong" <MIKE_ARMSTRONG@novell.com>,\n"Tim Weil" <TWEIL@novell.com>, "Victor Zhang" <VICTOR_ZHANG@novell.com>,\n"Bill Loomis" <BLOOMIS@svconf.com>,\n"Gobikrishnan Sundharraj" <GSUNDHARRAJ@volera.com>,\n"Jamshid Mahdavi" <MAHDAVI@volera.com>\nSubject: Champs are crowned!\nTo all Gump Tournament Participants:\n\nTim and I would like to thank you for participating in this year\'s\nForrest Gump Doubles Ping Pong Tournament.  We hope you enjoyed it.\nBefore we announce the champs (in case you haven\'t heard), please note\nthat the table will be moved to a more permanent location on the 4th\nfloor of Building B in a lobby near the break room.\n\nIn a grueling 5 game match where the lead changed hands three times,\n Liang and Yuyu  finally made it past Jimmy Wu and Armen\nGabrielian to be crowned our first official inter-corporate doubles\nchampions!  Congratualtions to  and Yuyu, first of all, and also\nto Jimmy and Armen who, at many times throughout the tournament, seemed\ninvincible!  (, Yuyu, we will have  trophies for both of you;\nthey should be ready for you to pick up in the afternoon tomorrow.)\n\nFinally, congratulations to all of you for making this such a fun\nevent!\n\nHope to see you around the tables...'
# 'Hast Du MS Project? Wenn nein, sollten wir es uns kaufen...\n\n-----Ursprüngliche Nachricht-----'
# 'fyi\nic habe 200 tdm verlangt und er ist nicht erschrocken\n\n-----Ursprüngliche Nachricht-----'
# 'Daimyo,\n\ngreat. Thanks a lot.\n\n\n\n-----Ursprüngliche Nachricht-----'
# 'Need attachment.\n\n-----Ursprüngliche Nachricht-----'
# 'Werner,\nkann ich bitte Deine Adresse, Tel etc haben'
# 'Hallo Regine,\n\nhat das Kopieren funktioniert ?\n\nHast Du eine Idee fuer morgen (Biergarten faellt ja wohl aus) ?\n\nCiao\nWerner'
# 'Werner,\nunsere Optionen sind $3 wert. Schriftlich nach Board-Meeting, weil dort ein Vorstoss von a D Can verhandelt wird, weitere Optionen zu vergeben.'
# "Thanks for forwarding. I'm very interested to participate.\n\n\n\n-----Ursprüngliche Nachricht-----"
# 'fyi\n\n\n\n-----Ursprüngliche Nachricht-----'
# 'Hallo Herr Hehl,\n\nwir haben den URL-Eintrag geswitcht. Jetzt besteht laut Auskunft unseres\nTechnikers allerdings wieder das gleiche Problem, das wir beim letzten Mal auch\nhatten (Sie wüssten schon, welches das sei). Mehr weiß ich leider auch nicht.\nFalls Sie nähere Informationen benötigen, können Sie sich direkt an Herrn Zeyer\nwenden (E-Mail lothar.zeyer@mannheimer.de oder Tel. 0621-457-2042.\n\nBitte geben Sie mir möglichst bald Bescheid, wann der Auftritt wieder über\nwap.mamax.com erreichbar ist, da wir eine Presseinfo zu diesem Thema herausgeben\nwollen.'
# "Mach' ich, \n\nciao\nWerner"
# 'have fun\n-----Ursprüngliche Nachricht-----'
# 'Ich verstehe nur noch minimal.\n\n\n\n-----Ursprüngliche Nachricht-----'
# 'Hallo Werner, mein Mann hatte gestern Prüfung und hat es geschafft. Noch vor\nwenigen Tagen hätte ich keinerlei Zweifel am bestehen gehabt - er ist\nnormalerweise die Ruhe selbst. Leider hatte er seit Mittwoch letzter Woche\nschlaflose Nächte und war psychisch echt total angespannt. Bin froh, dass es\njetzt gut ausgegangen ist!\nHabe heute Kokosmakronen gebacken - für mich fängt der Advent erst jetzt an;\nmorgen gehe ich mit einer ganz lieben Donauwörther Kollegin  zum Einkaufen\n(kommt höchst selten  vor, dass ich einen sog. Einkaufsbummel mache -\nmeistens mache ich eher einen "Kaufdauerlauf ohne Genuß" und finde nicht\ndas, was ich suche.\nHabe einen Urlaubs- bzw. Gleittag vor Weihnachten (17.12.) eingeplant; trotz\nzweier Beschwerden wegen langer Wartezeit. Dafür berate ich dann am\n02.01.02!!!!!\nSo long Marita'
# 'Hallo Werner,\n\nich habe für Dich einen Urlaubsschein ausgefüllt.\n\nViel Spaß\nKatja\n\n-----Ursprüngliche Nachricht-----'
# "I'll be there!\nUli.\n\n-----Ursprünglicher Termin-----"
# 'Hallo Werner,\n\nFrau Kruse vom MarketingTeam braucht Screenshots von mamax für den Anwenderbericht.\nWenn es geht auch einen von dem Handysimulator mit Berechnung beispielsweise.\nDas hatte ich schon probiert, aber offensichtlich bin ich dafür zu blöd.\n\nIch gebe Dir mal Ihre mail-Adresse, dann kannst Du ihr das direkt zumailen.\n\nKerstin.Kruse@MarketingTeam.de\n\nDanke\nKatja'
# 'Nun – das tut mir sehr leid zu hören! Es ist aber insofern schlimm, als ich in den letzten Wochen von fast allen Firmen, die bei der CeBIT in meiner unmittelbaren Nähe gestanden waren, unangenehme Dinge gehört habe (clickfish, razorfish, Canbox – und nun Ihr)..;-(((\n\nNaja – bei mir geht es wirklich so halbwegs, aber vielleicht auch weil ich vom reinen Software - / Hardware Geschäft weg bin und mich mehr auf Consulting, Strategieentwicklung und Projektmanagement konzentriere!\n\nAber schöne Sommermonate zu verbringen ist natürlich auch viel wert – bei mir ist Urlaub ja eben erst zu Jahresende in Sicht!\nHast Du schon konkrete Pläne für den Sommer oder einfach „Seele baumeln“ lassen (und das eine oder andere Bierchen trinken..;-)) Was wirst Du denn nach avocadoit machen – hast Du schon Ideen?! Ich persönlich werde ja leider keine Niederlassung in Düsseldorf eröffnen..;-)\n\nSei doch so lieb und sag mir rechtzeitig Bescheid, wenn Du diese E-Mail Adresse nicht mehr hast (genau so wie das Handy) – würde mich freuen, dann die aktuellen von Dir zu bekommen!?!?!?\n\nDamit noch einen schönen Tag und alles Liebe aus dem verregneten Wien\n\nGerhard\n\n____________________\nGerhard Holzer, MAS\nKIT HOLZER KEG\nKommunikation - Information - Technologie\n\n"more than bytes"\n\nTel.: +43 (0) 664 201 90 20\nFax: +43 (0) 2254 76 283\nE-Mail: gerhard.holzer@kit.at\n\nThe information contained in this electronic message and any\nattachments to this message are intended for the exclusive use of the addressee(s) and may contain confidential or privileged information. If you are not the intended recipient, destroy all copies of this message and any attachments.\n\n-----Ursprüngliche Nachricht-----'
# 'Werner, kannst Du mich mal bitte auf dem Handy anrufen? Auch heute oder\nmorgen.'
# 'Sehr geehrter Herr Schlegel,\n\nhier wie besprochen die abgeänderte Produktbeschreibung für den\nUnterausstellervertrag mit der Bitte um Freigabe:\n\nLösungen zur Verbindung bestehender           (35 Zeichen)\nInternetinhalte zu mobilen Endgeräten         (37 Zeichen)'
# "Ulrike Eder (ueder@avocadoit.ocm) hat Ihnen eine Yahoo! Schlagzeile geschickt.\n------------------------------------------------------------\nPersönliche Nachricht:\nFYI - wenn ihr's nicht schon gelesen habt... ;-)\n\nYahoo! Schlagzeilen - Handspring bessert beim VisorPhone nach\nhttp://de.news.yahoo.com/010507/51/1kz0e.html\n\nHinweis: Das Weiterversenden ist ausschließlich zu privaten\nund keinesfalls zu gewerblichen Zwecken gestattet.\n\n\n============================================================\nYahoo! Schlagzeilen -----------------> schlagzeilen.yahoo.de\nCoole Jobs bei Yahoo! -----------------------> jobs.yahoo.de"
# 'Sent: Tuesday, March 26, 2002 8:54 PM\n\n\nAlso, ich weiss natürlich nicht, was in England so diskutiert wurde, als die\nLtd. geschlossen wurde. Mir reicht es hier jedenfalls.\n\nDanke nochmals für die Zusammenarbeit und man sieht sich...hoffentlich\n\n\n\nPS: und ab sofort nur noch mailto:.federer@gmx.net\n\n\n\n<<bye.jpg>>'
# "schau'n wir mal ! Solltest Du mich zu sehr niedermachen, dann kann ich mich ja\nhinterher mit einem kleinen Bierchen troesten"
# 'AuLGoldschalt@aol.com; christine.stahl@dresdner-bank.com;\nlars.waldeck@das-baubuero.de; .menrad@dgbank-dip.de;\nOZIRENER@EEHFR.DE; rsilverton@avocadoit.com;\nsacha.kaiser@juliusbaer.com; Sebastian.Meinsen@dresdner-bank.com;\ny.bischoff@lampe-schwartze.de; h.paulus@icfag.de; t.lorz@icfag.de\nSubject: FW: alles nehmen einem die Computer auch nicht ab'
# 'Jetzt sind wir offiziell Partner ....\n\nhttp://newsroom.ac.com/news/dynamicpressrelease.cfm?ID=104'
# 'Et la derniere présentation.\n\nCordialement'
# 'Hallo werner, hoffe du bist nach unserem ausgiebigen Frühstück gut\nangekommen - werde dein Buch wohl nächste woche anfangen zu lesen! Nochmals\nDanke marita'
# 'Kimerlie,\nthanks to Rene that has been done for Germany already. See attached doc.\n\nRgds\n\n\n\n\n-----Ursprüngliche Nachricht-----'
# 'Hallo Herr Hoff,\n\nich moechte nur mal kurz nachfragen, ob Sie die Demo-Applikation\ngetestet haben; fuer ein kurzes Feedback waere ich Ihnen sehr\ndankbar'
# 'Anfrage Sun bezogen ...'
# ',\nRolf ist bis zum 23. September in Urlaub\nWerner'
