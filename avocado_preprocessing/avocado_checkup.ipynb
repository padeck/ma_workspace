# %% [markdown]
# ## Avocado EDA

# %%
import pandas as pd
import re
from tqdm import tqdm
tqdm.pandas()  # Register tqdm with pandas

# %%
df = pd.read_csv('emails.csv', low_memory=False)        # Write After

# %%
df.shape
# Out:
# (938035, 243)

# %%
for column in df.columns:
    print(column)
# Out:
# arrival_date
# cc_address
# create_date
# delete_after_submit
# delivery_report
# file_as
# flags
# importance
# message_cc_me
# message_recip_me
# message_to_me
# messageid
# modify_date
# original_sensitivity
# outlook_recipient_name
# outlook_sender_name
# priority
# processed_subject
# read_receipt
# recip_access
# recip_address
# reply_requested
# response_requested
# sender2_access
# sender2_address
# sender_access
# sender_address
# sensitivity
# sent_date
# sentto_address
# subject
# body_file_path
# body_content
# autoforward
# outlook_version
# in_reply_to
# reply_to
# Keywords
# bcc_address
# X-Mailer
# X-MimeOLE
# X-Received
# X-UIDL
# return_path_address
# X-Juno-Att
# X-Juno-Line-Breaks
# X-Juno-RefParts
# X-LSV-ListID
# X-List-Host
# X-URL
# X-Sender
# X-AMAZON-TRACK
# X-AMAZON-TRACK-2
# X-eGroups-Return
# X-Authentication-Warning
# X-MIMETrack
# X-Accept-Language
# X-apix
# X-ListID
# X-MsgID
# X-Att-Encode
# X-SohoMail-UID
# X-SohoMail-version
# X-Listprocessor
# X-SubID
# X-Server-Uuid
# X-WSS-ID
# X-To
# X-MnM-Date
# X-MnM-JobId
# X-MnM-MsgId
# X-MnM-Software
# X-Originating-IP
# X-cid
# X-Message-Id
# X-OriginalArrivalTime
# X-Lotus-FromDomain
# X-eGroups-Approved-By
# X-Sent
# X-AT_T-Hype
# X-Loop-Detect
# X-MIME-Autoconverted
# X-Magic-Cap-Form
# X-Actual-From
# X-MDRcpt-To
# X-MDRemoteIP
# X-MDaemon-Deliver-To
# X-Return-Path
# X-Internal-ID
# X-Uboat-Death-Message
# X-QPED-ID
# X-Mailer-Version
# X-Emacs-Acronym
# X-MailList-Unsubscribe-URL
# X-Types
# X-eGroups-From
# X-From
# X-Mozilla-Draft-Info
# X-MTS-LoopDetect
# X-MTS-Ticket
# X-DeepCanyon-Tag
# original_to
# X-WM-Posted-At
# X-Sender-Ip
# X-Sent-Mail
# X-Palm-Loop
# Allowed Attempts
# Attempts Remaining
# Completion Date
# Current Status
# Current Status Detail
# Entry Number
# Fax Number
# Pages Sent
# Process After
# Recipient Name
# Retry Interval
# Submitted
# X-Mozilla-Status
# X-Mozilla-Status2
# X-Complaints-To
# X-Trace
# X-VM-v5-Data
# X-Newsreader
# X-Comments-To
# X-WebsiteAccess-GMT
# X-WebsiteUser-IP
# X-LSMTP-Document-ID
# X-Attachments
# X-VM-Bookmark
# X-VM-Labels
# X-VM-Summary-Format
# X-VM-VHeader
# X-MS-TNEF-Correlator
# X-Face
# X-Orcl-Application
# Partial Message Id
# X-WebTV-Signature
# X-Loop
# X-Department
# X-Organization
# X-Quote
# X-MailCaster-ID
# X-Client
# X-Mailing-List
# X-Orcl-Priority
# X-MS-Attachment
# Files
# ForBugorIssue
# ReviewedBy
# original_cc
# AttachToActProp
# X-Disappearing-SendThisMsgDE
# X-NAV-TimeoutProtection0
# X-NAV-TimeoutProtection1
# X-NAV-TimeoutProtection2
# X-NAV-TimeoutProtection3
# X-NAV-TimeoutProtection4
# X-NAV-TimeoutProtection5
# X-NAV-TimeoutProtection6
# X-NAV-TimeoutProtection7
# X-Comment
# X-SubService
# X-EntryID
# X-Disappearing-EncryptAttachments
# X-Apparently-To
# X-BeenThere
# X-Mailman-Version
# X-Reply-To
# X-No-Archive
# X-UnityID
# X-UnityUser
# D
# Disappears
# X-Disappearing-Boilerplate-Body
# X-Disappearing-Expires-At
# X-Disappearing-User-Key-URLs
# X-PMFLAGS
# X-NAV-TimeoutProtection8
# X-NAV-TimeoutProtection9
# X-NAV-TimeoutProtection10
# X-NAV-TimeoutProtection11
# X-NAV-TimeoutProtection12
# X-NAV-TimeoutProtection13
# X-NAV-TimeoutProtection14
# X-NAV-TimeoutProtection15
# X-NAV-TimeoutProtection16
# X-NAV-TimeoutProtection17
# X-NAV-TimeoutProtection18
# X-MIMEOLE
# X-Sent-From
# X-DeliverBy
# X-MSMailPriority
# X-Oa
# X-Officeagent
# X-Info
# X-PMG-Msgid
# X-PMG-Recipient
# X-PMG-Userid
# X-Yahoo-Forwarded
# X-vsuite-type
# X-OpenMail-Hops
# X-BFT
# X-Apparently-From
# X-Mimeole
# X-Cq_Job
# X-Processed-By
# X-WDR-Disclaimer
# X-Sybari-Trust
# X-Header-Date
# X-Header-Partid
# X-Header-Pitchid
# X-Header-Userid
# X-Campaign
# X-Form
# X-Lyris-Type
# X-AddressID
# X-EM-Registration
# X-EM-Version
# x-receiver
# X-Failed-Recipients
# X-legal
# X-cc
# X-SLUIDL
# X-Engine
# X-Auto
# X-OptioDCS-Version
# X-CampaignID
# X-Interface
# X-sparklist-type
# Recipient Company
# X-Hops
# X-VirusChecked
# X-Authenticated-IP
# X-Authenticated-Sender
# X-Flags
# X-NAV-TimeoutProtection19
# X-NAV-TimeoutProtection20
# X-NAV-TimeoutProtection21
# X-NAV-TimeoutProtection22
# X-NAV-TimeoutProtection23
# X-NAV-TimeoutProtection24
# X-Talk21Ref

# %%
df.head()
# Out:
#            arrival_date                                     cc_address  \
# 0  2001-04-12T22:02:41Z  'ray_rahamin@hp.com'; Dan Baca; Elba Linscott
# 1  2000-04-24T23:06:15Z                                            NaN
# 2  2000-06-20T20:51:04Z                                            NaN
# 3  2000-09-12T17:01:08Z                                            NaN
# 4  2000-05-03T01:30:54Z                                   Wayne Thayer
#
#             create_date  delete_after_submit  delivery_report  \
# 0  2001-04-12T23:41:52Z                  0.0              0.0
# 1  2000-04-26T16:12:23Z                  0.0              1.0
# 2  2000-06-20T20:34:39Z                  0.0              0.0
# 3  2000-09-08T22:48:28Z                  0.0              0.0
# 4  2000-05-08T23:33:53Z                  0.0              0.0
#
#                       file_as  flags importance  message_cc_me  \
# 0                  Meshele Ko    1.0     normal            0.0
# 1               All Employees    1.0     normal            0.0
# 2  RisingStar White Paper.doc   17.0       high            0.0
# 3       'jbmcbryde@fedex.com'   17.0     normal            0.0
# 4         Meshele Ko (E-mail)    1.0     normal            0.0
#
#    message_recip_me  ...  X-Authenticated-IP X-Authenticated-Sender X-Flags  \
# 0               1.0  ...                 NaN                    NaN     NaN
# 1               0.0  ...                 NaN                    NaN     NaN
# 2               0.0  ...                 NaN                    NaN     NaN
# 3               0.0  ...                 NaN                    NaN     NaN
# 4               1.0  ...                 NaN                    NaN     NaN
#
#   X-NAV-TimeoutProtection19 X-NAV-TimeoutProtection20  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#   X-NAV-TimeoutProtection21 X-NAV-TimeoutProtection22  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#   X-NAV-TimeoutProtection23  X-NAV-TimeoutProtection24 X-Talk21Ref
# 0                       NaN                        NaN         NaN
# 1                       NaN                        NaN         NaN
# 2                       NaN                        NaN         NaN
# 3                       NaN                        NaN         NaN
# 4                       NaN                        NaN         NaN
#
# [5 rows x 243 columns]

# %%
df_man.shape
# Out:
# (937958, 13)

# %%
for column, value in df.iloc[20].items():
    print(str(column)+": "+str(value))
# Out:
# arrival_date: 2000-08-10T18:48:34Z
# cc_address: nan
# create_date: 2000-08-10T18:58:17Z
# delete_after_submit: 0.0
# delivery_report: 0.0
# file_as: security.doc
# flags: 25.0
# importance: normal
# message_cc_me: 0.0
# message_recip_me: 0.0
# message_to_me: 0.0
# messageid: <F57EA917353BD411B5BA00D0B708160C1745ED@mailhost.avocadoit.com>
# modify_date: 2000-08-10T18:47:20Z
# original_sensitivity: none
# outlook_recipient_name: nan
# outlook_sender_name: nan
# priority: normal
# processed_subject: Security
# read_receipt: 0.0
# recip_access: nan
# recip_address: nan
# reply_requested: 0.0
# response_requested: 0.0
# sender2_access: nan
# sender2_address: nan
# sender_access: nan
# sender_address: nan
# sensitivity: none
# sent_date: nan
# sentto_address: nan
# subject: Security
# body_file_path: text/162/162-000032-EM.txt
# body_content: Subject: Security
# Message-ID: <F57EA917353BD411B5BA00D0B708160C1745ED@mailhost.avocadoit.com>
#
# WAP:
# Typically, RSA security is used in the air, and SSL (Secure Sockets Layer) security on the wired network during WAP transmissions.
#
# Palm VII on Palm net is secured by ECC :
# They use a version of ECC technology that uses DESX data encryption from Certicom.  The key generated is 163-bit and it is equivalent to RSA 1024-bit keys.  Session keys are changed for every transmission to prevent passive attacks. Each message includes an MIC to verify message authenticity.  It allows to transport short highly secure messages to moved back and forth on the wireless network.
#
# On a phone call:
# The circuit switched network is a secure medium.
#
#
#
# Meshele Ko
# Director of Sales
#
#
#
# 3231 Scott Boulevard
# Santa Clara, CA  95054
# Direct: 408.562.8034  	Mobile: 408.836.9665
# Main: 408.562.8000 	Fax: 408.562.8100
# mko@avocadoit.com
# http://www.avocadoit.com
#
# autoforward: 1.0
# outlook_version: 9.0
# in_reply_to: nan
# reply_to: nan
# Keywords: nan
# bcc_address: nan
# X-Mailer: nan
# X-MimeOLE: nan
# X-Received: nan
# X-UIDL: nan
# return_path_address: nan
# X-Juno-Att: nan
# X-Juno-Line-Breaks: nan
# X-Juno-RefParts: nan
# X-LSV-ListID: nan
# X-List-Host: nan
# X-URL: nan
# X-Sender: nan
# X-AMAZON-TRACK: nan
# X-AMAZON-TRACK-2: nan
# X-eGroups-Return: nan
# X-Authentication-Warning: nan
# X-MIMETrack: nan
# X-Accept-Language: nan
# X-apix: nan
# X-ListID: nan
# X-MsgID: nan
# X-Att-Encode: nan
# X-SohoMail-UID: nan
# X-SohoMail-version: nan
# X-Listprocessor: nan
# X-SubID: nan
# X-Server-Uuid: nan
# X-WSS-ID: nan
# X-To: nan
# X-MnM-Date: nan
# X-MnM-JobId: nan
# X-MnM-MsgId: nan
# X-MnM-Software: nan
# X-Originating-IP: nan
# X-cid: nan
# X-Message-Id: nan
# X-OriginalArrivalTime: nan
# X-Lotus-FromDomain: nan
# X-eGroups-Approved-By: nan
# X-Sent: nan
# X-AT_T-Hype: nan
# X-Loop-Detect: nan
# X-MIME-Autoconverted: nan
# X-Magic-Cap-Form: nan
# X-Actual-From: nan
# X-MDRcpt-To: nan
# X-MDRemoteIP: nan
# X-MDaemon-Deliver-To: nan
# X-Return-Path: nan
# X-Internal-ID: nan
# X-Uboat-Death-Message: nan
# X-QPED-ID: nan
# X-Mailer-Version: nan
# X-Emacs-Acronym: nan
# X-MailList-Unsubscribe-URL: nan
# X-Types: nan
# X-eGroups-From: nan
# X-From: nan
# X-Mozilla-Draft-Info: nan
# X-MTS-LoopDetect: nan
# X-MTS-Ticket: nan
# X-DeepCanyon-Tag: nan
# original_to: nan
# X-WM-Posted-At: nan
# X-Sender-Ip: nan
# X-Sent-Mail: nan
# X-Palm-Loop: nan
# Allowed Attempts: nan
# Attempts Remaining: nan
# Completion Date: nan
# Current Status: nan
# Current Status Detail: nan
# Entry Number: nan
# Fax Number: nan
# Pages Sent: nan
# Process After: nan
# Recipient Name: nan
# Retry Interval: nan
# Submitted: nan
# X-Mozilla-Status: nan
# X-Mozilla-Status2: nan
# X-Complaints-To: nan
# X-Trace: nan
# X-VM-v5-Data: nan
# X-Newsreader: nan
# X-Comments-To: nan
# X-WebsiteAccess-GMT: nan
# X-WebsiteUser-IP: nan
# X-LSMTP-Document-ID: nan
# X-Attachments: nan
# X-VM-Bookmark: nan
# X-VM-Labels: nan
# X-VM-Summary-Format: nan
# X-VM-VHeader: nan
# X-MS-TNEF-Correlator: nan
# X-Face: nan
# X-Orcl-Application: nan
# Partial Message Id: nan
# X-WebTV-Signature: nan
# X-Loop: nan
# X-Department: nan
# X-Organization: nan
# X-Quote: nan
# X-MailCaster-ID: nan
# X-Client: nan
# X-Mailing-List: nan
# X-Orcl-Priority: nan
# X-MS-Attachment: nan
# Files: nan
# ForBugorIssue: nan
# ReviewedBy: nan
# original_cc: nan
# AttachToActProp: nan
# X-Disappearing-SendThisMsgDE: nan
# X-NAV-TimeoutProtection0: nan
# X-NAV-TimeoutProtection1: nan
# X-NAV-TimeoutProtection2: nan
# X-NAV-TimeoutProtection3: nan
# X-NAV-TimeoutProtection4: nan
# X-NAV-TimeoutProtection5: nan
# X-NAV-TimeoutProtection6: nan
# X-NAV-TimeoutProtection7: nan
# X-Comment: nan
# X-SubService: nan
# X-EntryID: nan
# X-Disappearing-EncryptAttachments: nan
# X-Apparently-To: nan
# X-BeenThere: nan
# X-Mailman-Version: nan
# X-Reply-To: nan
# X-No-Archive: nan
# X-UnityID: nan
# X-UnityUser: nan
# D: nan
# Disappears: nan
# X-Disappearing-Boilerplate-Body: nan
# X-Disappearing-Expires-At: nan
# X-Disappearing-User-Key-URLs: nan
# X-PMFLAGS: nan
# X-NAV-TimeoutProtection8: nan
# X-NAV-TimeoutProtection9: nan
# X-NAV-TimeoutProtection10: nan
# X-NAV-TimeoutProtection11: nan
# X-NAV-TimeoutProtection12: nan
# X-NAV-TimeoutProtection13: nan
# X-NAV-TimeoutProtection14: nan
# X-NAV-TimeoutProtection15: nan
# X-NAV-TimeoutProtection16: nan
# X-NAV-TimeoutProtection17: nan
# X-NAV-TimeoutProtection18: nan
# X-MIMEOLE: nan
# X-Sent-From: nan
# X-DeliverBy: nan
# X-MSMailPriority: nan
# X-Oa: nan
# X-Officeagent: nan
# X-Info: nan
# X-PMG-Msgid: nan
# X-PMG-Recipient: nan
# X-PMG-Userid: nan
# X-Yahoo-Forwarded: nan
# X-vsuite-type: nan
# X-OpenMail-Hops: nan
# X-BFT: nan
# X-Apparently-From: nan
# X-Mimeole: nan
# X-Cq_Job: nan
# X-Processed-By: nan
# X-WDR-Disclaimer: nan
# X-Sybari-Trust: nan
# X-Header-Date: nan
# X-Header-Partid: nan
# X-Header-Pitchid: nan
# X-Header-Userid: nan
# X-Campaign: nan
# X-Form: nan
# X-Lyris-Type: nan
# X-AddressID: nan
# X-EM-Registration: nan
# X-EM-Version: nan
# x-receiver: nan
# X-Failed-Recipients: nan
# X-legal: nan
# X-cc: nan
# X-SLUIDL: nan
# X-Engine: nan
# X-Auto: nan
# X-OptioDCS-Version: nan
# X-CampaignID: nan
# X-Interface: nan
# X-sparklist-type: nan
# Recipient Company: nan
# X-Hops: nan
# X-VirusChecked: nan
# X-Authenticated-IP: nan
# X-Authenticated-Sender: nan
# X-Flags: nan
# X-NAV-TimeoutProtection19: nan
# X-NAV-TimeoutProtection20: nan
# X-NAV-TimeoutProtection21: nan
# X-NAV-TimeoutProtection22: nan
# X-NAV-TimeoutProtection23: nan
# X-NAV-TimeoutProtection24: nan
# X-Talk21Ref: nan

# %%
new_cols = ["messageid", "sender_access", "outlook_sender_name", "outlook_recipient_name", "sentto_address", "cc_address", "subject", "processed_subject", "sent_date", "arrival_date", "body_file_path", "body_content", "in_reply_to"   ,  "Keywords",  ]
df_man = df.loc[:, new_cols]

# %%
df_man.head()
# Out:
#                                            messageid sender_access  \
# 0  <FC38A9406AA4D411AB62009027DE9DA5E6545D@HQEXCH01>            EX
# 1    <19B3B310D020D311B57E00105A9A55241D5975@COFFEE>            EX
# 2    <F57EA917353BD411B5BA00D0B708160C121B24@COFFEE>            EX
# 3    <9640A23C9075D411B5CB00D0B708160C23A93D@COFFEE>            EX
# 4    <019D8990549CD3118A30009027D609CD25BF69@EXSRVR>          SMTP
#
#    outlook_sender_name outlook_recipient_name         sentto_address  \
# 0    Fortunata Hermoso             Meshele Ko             Meshele Ko
# 1  Paiman Komeilizadeh             Meshele Ko          All Employees
# 2           Meshele Ko                    NaN  Piyush Goel; Dan Baca
# 3           Meshele Ko                    NaN  'jbmcbryde@fedex.com'
# 4         Cindy Hilker             Meshele Ko    Meshele Ko (E-mail)
#
#                                       cc_address  \
# 0  'ray_rahamin@hp.com'; Dan Baca; Elba Linscott
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                   Wayne Thayer
#
#                                              subject  \
# 0  Fw: RE: AvocadoIT's CEO committed to winning B...
# 1           Expense reimbursement request- Amendment
# 2                                    FW: Information
# 3                                              Fedex
# 4                  Icon and graphic for our WAP APPs
#
#                                    processed_subject             sent_date  \
# 0  AvocadoIT's CEO committed to winning Banamex deal  2001-04-12T22:02:41Z
# 1           Expense reimbursement request- Amendment  2000-04-24T23:06:06Z
# 2                                        Information  2000-06-20T20:51:04Z
# 3                                              Fedex  2000-09-12T17:01:08Z
# 4                  Icon and graphic for our WAP APPs  2000-05-03T01:27:13Z
#
#            arrival_date              body_file_path  \
# 0  2001-04-12T22:02:41Z  text/162/162-000001-EM.txt
# 1  2000-04-24T23:06:15Z  text/162/162-000003-EM.txt
# 2  2000-06-20T20:51:04Z  text/162/162-000004-EM.txt
# 3  2000-09-12T17:01:08Z  text/162/162-000005-EM.txt
# 4  2000-05-03T01:30:54Z  text/162/162-000006-EM.txt
#
#                                         body_content in_reply_to Keywords
# 0  From: "Fortunata Hermoso" <fortunata.hermoso@a...         NaN      NaN
# 1  From: "Paiman Komeilizadeh" <pkomeilizadeh@avo...         NaN      NaN
# 2  From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...         NaN      NaN
# 3  From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...         NaN      NaN
# 4  Received: from exsrvr.homebid.com (197-175-161...         NaN      NaN

# %%
df_man.to_parquet('avocado_light.parquet', engine='pyarrow', compression='snappy')

# %% [markdown]
# ### Filter DF into sender_access: EX / SMTP / NaN

# %%
df_ex = df_man[df_man['sender_access'] == 'EX']

df_nan = df_man[(df_man['sender_access'] != 'SMTP' ) & (df_man['sender_access'] != 'EX') ]

# %% [markdown]
# #### Sender Type EX

# %%
df_ex.shape
# Out:
# (600564, 14)

# %%
df_ex['body_content'].str.contains('Message-ID:', case=False).sum()
# Out:
# np.int64(600564)

# %%
df_ex.loc[:, 'body_content'] = df_ex['body_content'].fillna('')

# Define the regex pattern
pattern = re.compile(r'message-id:\s*<[^>]+>\s*(.*)', re.IGNORECASE | re.DOTALL)

# Filter DataFrame to get only rows that contain the Message-ID pattern
df_ex = df_ex[df_ex['body_content'].str.contains(r'message-id:\s*<[^>]+>', case=False, regex=True)]

# Extract the text following the Message-ID using .loc to avoid SettingWithCopyWarning
df_ex.loc[:, 'extracted_text'] = df_ex['body_content'].str.extract(pattern, expand=False)

# %%
df_ex.head()
# Out:
#                                            messageid sender_access  \
# 0  <FC38A9406AA4D411AB62009027DE9DA5E6545D@HQEXCH01>            EX
# 1    <19B3B310D020D311B57E00105A9A55241D5975@COFFEE>            EX
# 2    <F57EA917353BD411B5BA00D0B708160C121B24@COFFEE>            EX
# 3    <9640A23C9075D411B5CB00D0B708160C23A93D@COFFEE>            EX
# 5    <19B3B310D020D311B57E00105A9A55243C6C85@COFFEE>            EX
#
#    outlook_sender_name outlook_recipient_name  \
# 0    Fortunata Hermoso             Meshele Ko
# 1  Paiman Komeilizadeh             Meshele Ko
# 2           Meshele Ko                    NaN
# 3           Meshele Ko                    NaN
# 5        Ron Silverton             Meshele Ko
#
#                                       sentto_address  \
# 0                                         Meshele Ko
# 1                                      All Employees
# 2                              Piyush Goel; Dan Baca
# 3                              'jbmcbryde@fedex.com'
# 5  Marketing&Business Development; Sales Team; Ex...
#
#                                       cc_address  \
# 0  'ray_rahamin@hp.com'; Dan Baca; Elba Linscott
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 5                                            NaN
#
#                                              subject  \
# 0  Fw: RE: AvocadoIT's CEO committed to winning B...
# 1           Expense reimbursement request- Amendment
# 2                                    FW: Information
# 3                                              Fedex
# 5               m-commerce over $120 billion by 2008
#
#                                    processed_subject             sent_date  \
# 0  AvocadoIT's CEO committed to winning Banamex deal  2001-04-12T22:02:41Z
# 1           Expense reimbursement request- Amendment  2000-04-24T23:06:06Z
# 2                                        Information  2000-06-20T20:51:04Z
# 3                                              Fedex  2000-09-12T17:01:08Z
# 5                 ASG News & Analysis - 6 April 2000  2000-04-10T19:19:56Z
#
#            arrival_date              body_file_path  \
# 0  2001-04-12T22:02:41Z  text/162/162-000001-EM.txt
# 1  2000-04-24T23:06:15Z  text/162/162-000003-EM.txt
# 2  2000-06-20T20:51:04Z  text/162/162-000004-EM.txt
# 3  2000-09-12T17:01:08Z  text/162/162-000005-EM.txt
# 5  2000-04-10T19:19:57Z  text/162/162-000008-EM.txt
#
#                                         body_content in_reply_to Keywords  \
# 0  From: "Fortunata Hermoso" <fortunata.hermoso@a...         NaN      NaN
# 1  From: "Paiman Komeilizadeh" <pkomeilizadeh@avo...         NaN      NaN
# 2  From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...         NaN      NaN
# 3  From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...         NaN      NaN
# 5  From: "Ron Silverton" <rsilverton@avocadoit.co...         NaN      NaN
#
#                                       extracted_text preceding_conversation
# 0  Fyi on Venks commitment on Banamex. The next s...                    NaN
# 1  Dear  friends,\r\n\r\n\r\nTo expedite the expe...                    NaN
# 2  Here is the information from Send.com.  They h...                    NaN
# 3  Hello Jim,\r\n\r\nI am following up on a piece...                    NaN
# 5  Attached are some recent projections from Merr...                    NaN

# %% [markdown]
# ##### Extract Original Message

# %%
df_ex.loc[0]['extracted_text']
# Out:
# 'Fyi on Venks commitment on Banamex. The next step is to set a conference call with Nicollo and Venk next week. EP is committed to do whatever it takes to close this accoiunt.\r\n\r\nWe have a lot of support. Let\'s keep the communcation going. Please use me to escalate any support needed to close this account.\r\n--------------------------\r\nFortunata Hermoso\r\nAvocadoIT, Inc.\r\nGlobal Alliance Manager\r\nMobile Phone: 408.464.8998\r\nemail: fortunata.hermoso@avocadoit.com\r\n\r\n\r\n-----Original Message-----\r\nFrom: Venk Shukla <shukla@avocadoit.com>\r\nTo: \'DEPERALTA,AIREEN (HP-Cupertino,ex1)\' <aireen_deperalta@hp.com>; Venk Shukla <shukla@avocadoit.com>; ARENAS,MARTHA (HP-Mexico,ex1) <martha_arenas@hp.com>; SPATARO,NICCOLO (HP-Mexico,ex1) <niccolo_spataro@hp.com>\r\nCC: KOMORI,ZENKI (HP-Mexico,ex1) <zenki_komori@hp.com>; ZAMORA,EDUARDO (HP-Mexico,ex1) <eduardo_zamora@hp.com>; Fortunata Hermoso <Fortunata.Hermoso@avocadoit.com>; WATSON,JULIE (HP-Cupertino,ex1) <julie_watson@hp.com>; GRATTON,RANDOLPH (HP-UK,unix1) <randolph_gratton@hp.com>; Ray Rahamin <Ray.Rahamin@avocadoit.com>\r\nSent: Thu Apr 12 14:11:07 2001\r\nSubject: RE: AvocadoIT\'s CEO committed to winning Banamex deal\r\n\r\nThanks for your initiative. We look to Benamex as a potential "anchor" account for our banking industry initiative. Goodwill and great reference from anchor accounts are vital to our strategy for success. Our existing customers such as ETrade and Alaska Airlines have nothing but great things to say about our level of commitment to them. We want to add Benamex to this list as well. Winning this account is even more crucial because of our connection to HP. We hope our success here will provide a model for how to work together to crack big accounts.  I am excited about this opportunity and am happy to offer whatever help I can provide in moving the sales process forward.\r\n\r\n\r\n\r\nVenktesh Shukla\r\nChief Executive Officer\r\n\r\nAvocadoIT, Inc.\r\n2211 No. First Street, Ste. 200\r\nSan Jose, CA  95131\r\n\r\nDirect:   (408) 562-8010\r\nPager:   (888) 763-0797\r\nFax:      (408) 562-8108\r\n\r\n\r\n-----Original Message-----\r\nFrom: DEPERALTA,AIREEN (HP-Cupertino,ex1)\r\n[mailto:aireen_deperalta@hp.com]\r\nSent: Wednesday, April 11, 2001 1:51 PM\r\nTo: \'venk.shukla@avocadoit.com\'; ARENAS,MARTHA (HP-Mexico,ex1);\r\nSPATARO,NICCOLO (HP-Mexico,ex1)\r\nCc: KOMORI,ZENKI (HP-Mexico,ex1); ZAMORA,EDUARDO (HP-Mexico,ex1);\r\n\'fortunata hermoso\'; WATSON,JULIE (HP-Cupertino,ex1); GRATTON,RANDOLPH\r\n(HP-UK,unix1)\r\nSubject: AvocadoIT\'s CEO committed to winning Banamex deal\r\n\r\n\r\nHola, Martha and Niccolo,\r\n\r\nI would like to introduce you to Venk Shukla, CEO of AvocadoIT, one of the\r\nE-services Partner Division\'s (ESPD) mobile partners. We are currently\r\nworking with them on creating a qualified worldwide funnel and closing some\r\ndeals. I am their Sales Engagement manager incented to making this happen,\r\nand I have been in touch with Eduardo and Zenki to provide help in moving\r\nthe process along.\r\n\r\nVenk is making himself available to help win the deal at Banamex against\r\nEdify/Unisys. He\'s aware that Unisys is the incumbent since they implemented\r\nBanamex\'s internet banking solution and may have an advantage. Please feel\r\nfree to pull him in when talking to the executives at Banamex so that we can\r\nprovide a unified team. His number is 408-562-8010,\r\nVenk.Shukla@avocadoit.com. I\'ve copied Venk on this message.\r\n\r\nVenk, \r\n\r\nThe Mexico team is doing their best to win this deal, also. Banamex is one\r\nof our "Must Win" accounts, so you can be sure that all levels of HP\r\nmanagement are going to get involved to win this one. Marta is the GM of\r\nFinancial Services and Nicolo is the GM of HPC in Mexico. They will be\r\nmeeting with one of the Banamex directors next week. HP Mexico has a good\r\nrelationship with Banamex, who is one of our top customers, so this should\r\nhelp us in the decision-ma ...

# %%
# Adjust the search string to capture exactly five dashes, spaces, and words
search_string = r"-{5}[\w\s]+-{5}"

# Regex pattern to match and capture text after the search string
pattern = re.compile(rf'{search_string}[\r\n]*(.*)', re.DOTALL)

# Extract text after the search string into 'preceding_conversation'
df_ex['preceding_conversation'] = df_ex['extracted_text'].str.extract(pattern, expand=False)

# Remove the search string and everything after it from 'extracted_text'
df_ex['extracted_text'] = df_ex['extracted_text'].str.replace(pattern, '', regex=True).str.strip()

# %%
df_ex.shape
# Out:
# (600564, 16)

# %%
df_ex['extracted_text'].str.contains('In-Reply-To').sum()
# Out:
# np.int64(240095)

# %%
# Apply the regex pattern to remove matching lines from 'extracted_text' column
df_ex['extracted_text'] = df_ex['extracted_text'].replace(r'^In-Reply-To: <[^>]*>\s*', '', regex=True)

# %%
print(df_ex.iloc[0]['extracted_text'])
# Out:
# Fyi on Venks commitment on Banamex. The next step is to set a conference call with Nicollo and Venk next week. EP is committed to do whatever it takes to close this accoiunt.
#
# We have a lot of support. Let's keep the communcation going. Please use me to escalate any support needed to close this account.
# --------------------------
# Fortunata Hermoso
# AvocadoIT, Inc.
# Global Alliance Manager
# Mobile Phone: 408.464.8998
# email: fortunata.hermoso@avocadoit.com

# %%
df_ex['extracted_text'].str.contains('In-Reply-To').sum()
# Out:
# np.int64(1)

# %%
pattern = re.compile(
    r'(From:.*|Sent:.*|To:.*|Subject:.*)(?:\n|\r\n|$)', re.IGNORECASE | re.MULTILINE
)

# Extract matching lines into 'preceding_conversation'
df_ex['preceding_conversation'] = df_ex['extracted_text'].str.extract(
    rf'((From:.*\n.*\n.*\n.*\n)(.*))', expand=False
)[0]

# Remove matching lines from 'extracted_text'
df_ex['extracted_text'] = df_ex['extracted_text'].str.replace(pattern, '', regex=True).str.strip()

# %% [markdown]
# #### Sender Type SMTP

# %%
df_smtp = df_man[df_man['sender_access'] == 'SMTP']

# %%
df_smtp.shape
# Out:
# (333599, 14)

# %%
df_smtp.iloc[0]['body_content']
# Out:
# 'Received: from exsrvr.homebid.com (197-175-161-216.customers.uswest.net [216.161.175.197]) by coffee.avocadoit.com with SMTP (Microsoft Exchange Internet Mail Service Version 5.5.2448.0)\r\n\tid J5NF4M7L; Tue, 2 May 2000 18:30:53 -0700\r\nReceived: by EXSRVR with Internet Mail Service (5.5.2448.0)\r\n\tid <JGX7RSRQ>; Tue, 2 May 2000 18:27:20 -0700\r\nMessage-ID: <019D8990549CD3118A30009027D609CD25BF69@EXSRVR>\r\nFrom: Cindy Hilker <chilker@homebid.com>\r\nTo: "Meshele Ko (E-mail)" <mko@avocadoit.com>\r\nCc: Wayne Thayer <wthayer@homebid.com>\r\nSubject: Icon and graphic for our WAP APPs\r\nDate: Tue, 2 May 2000 18:27:13 -0700 \r\nMIME-Version: 1.0\r\nX-Mailer: Internet Mail Service (5.5.2448.0)\r\nContent-Type: multipart/alternative;\r\n\tboundary="----_=_NextPart_001_01BFB49E.B93D8574"\r\n\r\nThis message is in MIME format. Since your mail reader does not understand\r\nthis format, some or all of this message may not be legible.\r\n\r\n------_=_NextPart_001_01BFB49E.B93D8574\r\nContent-Type: text/plain;\r\n\tcharset="iso-8859-1"\r\n\r\n------_=_NextPart_001_01BFB49E.B93D8574\r\nContent-Type: text/html;\r\n\tcharset="iso-8859-1"\r\nContent-Transfer-Encoding: quoted-printable\r\n\r\n------_=_NextPart_001_01BFB49E.B93D8574--\r\n\r\nMeshele: \r\n\r\nI forgot to mention in our call today, are there any plans to create a custom Palm icon for the Homebid app? Also, we noticed that the Homebid logo on the sample front page does not render very well, are there any plans to do this over with a cleaner logo? We can send you graphics source files if that will help.\r\n\r\nThanks, \r\n\r\nCindy\r\n\r\n\r\n........................................................ \r\nCynthia Hilker \r\nInformation Architect \r\nHomebid.com \r\n8700 N. Gainey Center Drive Suite 150 \r\nScottsdale AZ 85258 \r\n(480) 609-4633 direct \r\n(602) 617-6072 mobile \r\n(480) 609-4646 fax \r\nchilker@homebid.com \r\nwww.homebid.com\r\n'

# %%
pattern = r"Received.*?\\r\\n\\r\\n"

# Apply the regex pattern to 'body_content' column and replace matches with an empty string
df_smtp.loc[:, 'extracted_text'] = df_smtp['body_content'].str.replace(pattern, '', regex=True)
# Out:
# /var/folders/vh/4lm899sj0tdgnf9d98kzk1800000gn/T/ipykernel_99619/4141530496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_smtp.loc[:, 'extracted_text'] = df_smtp['body_content'].str.replace(pattern, '', regex=True)

# %%
df_smtp.iloc[0]['extracted_text']
# Out:
# 'Received: from exsrvr.homebid.com (197-175-161-216.customers.uswest.net [216.161.175.197]) by coffee.avocadoit.com with SMTP (Microsoft Exchange Internet Mail Service Version 5.5.2448.0)\r\n\tid J5NF4M7L; Tue, 2 May 2000 18:30:53 -0700\r\nReceived: by EXSRVR with Internet Mail Service (5.5.2448.0)\r\n\tid <JGX7RSRQ>; Tue, 2 May 2000 18:27:20 -0700\r\nMessage-ID: <019D8990549CD3118A30009027D609CD25BF69@EXSRVR>\r\nFrom: Cindy Hilker <chilker@homebid.com>\r\nTo: "Meshele Ko (E-mail)" <mko@avocadoit.com>\r\nCc: Wayne Thayer <wthayer@homebid.com>\r\nSubject: Icon and graphic for our WAP APPs\r\nDate: Tue, 2 May 2000 18:27:13 -0700 \r\nMIME-Version: 1.0\r\nX-Mailer: Internet Mail Service (5.5.2448.0)\r\nContent-Type: multipart/alternative;\r\n\tboundary="----_=_NextPart_001_01BFB49E.B93D8574"\r\n\r\nThis message is in MIME format. Since your mail reader does not understand\r\nthis format, some or all of this message may not be legible.\r\n\r\n------_=_NextPart_001_01BFB49E.B93D8574\r\nContent-Type: text/plain;\r\n\tcharset="iso-8859-1"\r\n\r\n------_=_NextPart_001_01BFB49E.B93D8574\r\nContent-Type: text/html;\r\n\tcharset="iso-8859-1"\r\nContent-Transfer-Encoding: quoted-printable\r\n\r\n------_=_NextPart_001_01BFB49E.B93D8574--\r\n\r\nMeshele: \r\n\r\nI forgot to mention in our call today, are there any plans to create a custom Palm icon for the Homebid app? Also, we noticed that the Homebid logo on the sample front page does not render very well, are there any plans to do this over with a cleaner logo? We can send you graphics source files if that will help.\r\n\r\nThanks, \r\n\r\nCindy\r\n\r\n\r\n........................................................ \r\nCynthia Hilker \r\nInformation Architect \r\nHomebid.com \r\n8700 N. Gainey Center Drive Suite 150 \r\nScottsdale AZ 85258 \r\n(480) 609-4633 direct \r\n(602) 617-6072 mobile \r\n(480) 609-4646 fax \r\nchilker@homebid.com \r\nwww.homebid.com\r\n'

# %% [markdown]
# #### Sender Type not available

# %%
df_nan.shape
# Out:
# (3872, 14)

# %% [markdown]
# ### Next Chapter

# %%
for column, value in df_man.iloc[0].items():
    print(str(column)+": "+str(value))
# Out:
# messageid: <FC38A9406AA4D411AB62009027DE9DA5E6545D@HQEXCH01>
# outlook_sender_name: Fortunata Hermoso
# outlook_recipient_name: Meshele Ko
# sentto_address: Meshele Ko
# cc_address: 'ray_rahamin@hp.com'; Dan Baca; Elba Linscott
# subject: Fw: RE: AvocadoIT's CEO committed to winning Banamex deal
# processed_subject: AvocadoIT's CEO committed to winning Banamex deal
# sent_date: 2001-04-12T22:02:41Z
# arrival_date: 2001-04-12T22:02:41Z
# body_file_path: text/162/162-000001-EM.txt
# body_content: From: "Fortunata Hermoso" <fortunata.hermoso@avocadoit.com>
# To: "Meshele Ko" <mko@avocadoit.com>
# Cc: ray_rahamin@hp.com, "Dan Baca" <dbaca@avocadoit.com>, "Elba Linscott" <elinscott@avocadoit.com>
# Subject: Fw: RE: AvocadoIT's CEO committed to winning Banamex deal
# Date: 12 Apr 2001 22:02:41 UTC
# Message-ID: <FC38A9406AA4D411AB62009027DE9DA5E6545D@HQEXCH01>
#
# Fyi on Venks commitment on Banamex. The next step is to set a conference call with Nicollo and Venk next week. EP is committed to do whatever it takes to close this accoiunt.
#
# We have a lot of support. Let's keep the communcation going. Please use me to escalate any support needed to close this account.
# --------------------------
# Fortunata Hermoso
# AvocadoIT, Inc.
# Global Alliance Manager
# Mobile Phone: 408.464.8998
# email: fortunata.hermoso@avocadoit.com
#
#
# -----Original Message-----
# From: Venk Shukla <shukla@avocadoit.com>
# To: 'DEPERALTA,AIREEN (HP-Cupertino,ex1)' <aireen_deperalta@hp.com>; Venk Shukla <shukla@avocadoit.com>; ARENAS,MARTHA (HP-Mexico,ex1) <martha_arenas@hp.com>; SPATARO,NICCOLO (HP-Mexico,ex1) <niccolo_spataro@hp.com>
# CC: KOMORI,ZENKI (HP-Mexico,ex1) <zenki_komori@hp.com>; ZAMORA,EDUARDO (HP-Mexico,ex1) <eduardo_zamora@hp.com>; Fortunata Hermoso <Fortunata.Hermoso@avocadoit.com>; WATSON,JULIE (HP-Cupertino,ex1) <julie_watson@hp.com>; GRATTON,RANDOLPH (HP-UK,unix1) <randolph_gratton@hp.com>; Ray Rahamin <Ray.Rahamin@avocadoit.com>
# Sent: Thu Apr 12 14:11:07 2001
# Subject: RE: AvocadoIT's CEO committed to winning Banamex deal
#
# Thanks for your initiative. We look to Benamex as a potential "anchor" account for our banking industry initiative. Goodwill and great reference from anchor accounts are vital to our strategy for success. Our existing customers such as ETrade and Alaska Airlines have nothing but great things to say about our level of commitment to them. We want to add Benamex to this list as well. Winning this account is even more crucial because of our connection to HP. We hope our success here will provide a model for how to work together to crack big accounts.  I am excited about this opportunity and am happy to offer whatever help I can provide in moving the sales process forward.
#
#
#
# Venktesh Shukla
# Chief Executive Officer
#
# AvocadoIT, Inc.
# 2211 No. First Street, Ste. 200
# San Jose, CA  95131
#
# Direct:   (408) 562-8010
# Pager:   (888) 763-0797
# Fax:      (408) 562-8108
#
#
# -----Original Message-----
# From: DEPERALTA,AIREEN (HP-Cupertino,ex1)
# [mailto:aireen_deperalta@hp.com]
# Sent: Wednesday, April 11, 2001 1:51 PM
# To: 'venk.shukla@avocadoit.com'; ARENAS,MARTHA (HP-Mexico,ex1);
# SPATARO,NICCOLO (HP-Mexico,ex1)
# Cc: KOMORI,ZENKI (HP-Mexico,ex1); ZAMORA,EDUARDO (HP-Mexico,ex1);
# 'fortunata hermoso'; WATSON,JULIE (HP-Cupertino,ex1); GRATTON,RANDOLPH
# (HP-UK,unix1)
# Subject: AvocadoIT's CEO committed to winning Banamex deal
#
#
# Hola, Martha and Niccolo,
#
# I would like to introduce you to Venk Shukla, CEO of AvocadoIT, one of the
# E-services Partner Division's (ESPD) mobile partners. We are currently
# working with them on creating a qualified worldwide funnel and closing some
# deals. I am their Sales Engagement manager incented to making this happen,
# and I have been in touch with Eduardo and Zenki to provide help in moving
# the process along.
#
# Venk is making himself available to help win the deal at Banamex against
# Edify/Unisys. He's aware that Unisys is the incumbent since they implemented
# Banamex's internet banking solution and may have an advantage. Please feel
# free to pull him in when talking to the executives at Banamex so that we can
# provide a unified team. His number is 408-562-8010,
# Venk.Shukla@avocadoit.com. I've copied Venk on this message.
#
# Venk,
#
# The Mexico team is doing their best to win this deal, also. Banamex is one
# of our "Must Win" accounts, so you can be sure that all levels of HP
# management are going to get involved to win this one. Marta is the GM of
# Financial Services and Nicolo is the GM of HPC in Mexico. They will be
# meeting with one of the Banamex directors next week. HP Mexico has a good
# relationship with Banamex, who is one of our top customers, so this should
# help us in the decision-making.
#
# Thank you for offering your services and showing your commitment to close
# Banamex. Fortunata and I will keep you updated as these discussions
# progress.
#
# Let me know if anyone needs anything else,
#
# -Aireen de Peralta
# tn 447-8740
#
# in_reply_to: nan
# Keywords: nan

# %%
df_man = df_man.sort_values(by="arrival_date")

# %%
df_man.head()
# Out:
#                                                 messageid  \
# 50737     <F57EA917353BD411B5BA00D0B708160C1EE52C@COFFEE>
# 50186     <F57EA917353BD411B5BA00D0B708160C1EE4BF@COFFEE>
# 437320  <FD38A9406AA4D411AB62009027DE9DA501FD12AE@HQEX...
# 679010               <001801a8ea3a$9add1120$0eb409ca@nec>
# 678745               <000001a8ea42$96c5ba80$6f9309ca@nec>
#
#              outlook_sender_name outlook_recipient_name  \
# 50737   blackbird@MAIL.SERVE.COM        Marcia Kadanoff
# 50186   blackbird@MAIL.SERVE.COM        Marcia Kadanoff
# 437320                  eFax.com          Chris Quinter
# 679010                     kurag      Srikanth Raghavan
# 678745                     kurag      Srikanth Raghavan
#
#                      sentto_address                    cc_address  \
# 50737   MAGICCAP@LISTSERV.BROWN.EDU                           NaN
# 50186   MAGICCAP@LISTSERV.BROWN.EDU                           NaN
# 437320      cquinter@apptricity.com                           NaN
# 679010            Srikanth Raghavan  srividhya_raghavan@yahoo.com
# 678745            Srikanth Raghavan                           NaN
#
#                                                   subject  \
# 50737                             Re: Presto Mail and MSN
# 50186                               Re: PIC-1000 FOR SALE
# 437320  FAX FROM 215  785 214 at 2001-03-23 20:23:44 2...
# 679010                                       Re: 10th.day
# 678745                                       Re: 10th.day
#
#                                         processed_subject  \
# 50737                                 Presto Mail and MSN
# 50186                                   PIC-1000 FOR SALE
# 437320  FAX FROM 215  785 214 at 2001-03-23 20:23:44 2...
# 679010                                           10th.day
# 678745                                           10th.day
#
#                    sent_date          arrival_date  \
# 50737   1601-01-01T00:00:00Z  2000-06-30T22:50:41Z
# 50186   1601-01-01T00:00:00Z  2000-05-16T17:41:10Z
# 437320  1601-01-01T00:00:00Z  2001-03-23T20:23:54Z
# 679010  1980-01-04T07:32:29Z  2002-08-09T11:20:08Z
# 678745  1980-01-04T08:44:49Z  2002-08-23T10:17:37Z
#
#                     body_file_path  \
# 50737   text/161/161-016365-EM.txt
# 50186   text/161/161-015023-EM.txt
# 437320  text/040/040-000255-EM.txt
# 679010  text/235/235-029265-EM.txt
# 678745  text/235/235-028999-EM.txt
#
#                                              body_content in_reply_to Keywords
# 50737   Return-Path: <owner-magiccap@LISTSERV.BROWN.ED...         NaN      NaN
# 50186   Return-Path: <owner-magiccap@LISTSERV.BROWN.ED...         NaN      NaN
# 437320  Received: from boi1-media2.j2int.com (209.210....         NaN      NaN
# 679010  Received: from mailer.avocadoit.com (10.7.1.4 ...         NaN      NaN
# 678745  Received: from mailer.avocadoit.com (10.7.1.4 ...         NaN      NaN

# %%
df_man = df_man.dropna(subset=['body_content'])

# %%
df_man.to_csv('avocado_light.csv')

# %%
df_man.head()
# Out:
#                                            messageid  outlook_sender_name  \
# 0  <FC38A9406AA4D411AB62009027DE9DA5E6545D@HQEXCH01>    Fortunata Hermoso
# 1    <19B3B310D020D311B57E00105A9A55241D5975@COFFEE>  Paiman Komeilizadeh
# 2    <F57EA917353BD411B5BA00D0B708160C121B24@COFFEE>           Meshele Ko
# 3    <9640A23C9075D411B5CB00D0B708160C23A93D@COFFEE>           Meshele Ko
# 4    <019D8990549CD3118A30009027D609CD25BF69@EXSRVR>         Cindy Hilker
#
#   outlook_recipient_name         sentto_address  \
# 0             Meshele Ko             Meshele Ko
# 1             Meshele Ko          All Employees
# 2                    NaN  Piyush Goel; Dan Baca
# 3                    NaN  'jbmcbryde@fedex.com'
# 4             Meshele Ko    Meshele Ko (E-mail)
#
#                                       cc_address  \
# 0  'ray_rahamin@hp.com'; Dan Baca; Elba Linscott
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                   Wayne Thayer
#
#                                              subject  \
# 0  Fw: RE: AvocadoIT's CEO committed to winning B...
# 1           Expense reimbursement request- Amendment
# 2                                    FW: Information
# 3                                              Fedex
# 4                  Icon and graphic for our WAP APPs
#
#                                    processed_subject             sent_date  \
# 0  AvocadoIT's CEO committed to winning Banamex deal  2001-04-12T22:02:41Z
# 1           Expense reimbursement request- Amendment  2000-04-24T23:06:06Z
# 2                                        Information  2000-06-20T20:51:04Z
# 3                                              Fedex  2000-09-12T17:01:08Z
# 4                  Icon and graphic for our WAP APPs  2000-05-03T01:27:13Z
#
#            arrival_date              body_file_path  \
# 0  2001-04-12T22:02:41Z  text/162/162-000001-EM.txt
# 1  2000-04-24T23:06:15Z  text/162/162-000003-EM.txt
# 2  2000-06-20T20:51:04Z  text/162/162-000004-EM.txt
# 3  2000-09-12T17:01:08Z  text/162/162-000005-EM.txt
# 4  2000-05-03T01:30:54Z  text/162/162-000006-EM.txt
#
#                                         body_content in_reply_to Keywords
# 0  From: "Fortunata Hermoso" <fortunata.hermoso@a...         NaN      NaN
# 1  From: "Paiman Komeilizadeh" <pkomeilizadeh@avo...         NaN      NaN
# 2  From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...         NaN      NaN
# 3  From: "Meshele Ko" <mko@avocadoit.com>\r\nTo: ...         NaN      NaN
# 4  Received: from exsrvr.homebid.com (197-175-161...         NaN      NaN

# %%
ctr = 0
def extract_email_text(row):
    global ctr
    if "Message-ID:" in row['body_content']: 
        ctr += 1

# %%
df_man.apply(extract_email_text, axis=1)
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 938030    None
# 938031    None
# 938032    None
# 938033    None
# 938034    None
# Length: 937958, dtype: object

# %%
ctr
# Out:
# 847441
